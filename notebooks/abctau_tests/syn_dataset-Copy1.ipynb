# %% [markdown]
# Modified "Tutorial 1: How to use abcTau package to fit autocorrelations or PSDs" from the abcTau repo

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

import pickle
import numpy as np
import pandas as pd
from scipy import stats

# add the path to the abcTau package
import sys
#sys.path.append('./abcTau')
sys.path.append('C:\\Users\\ipochino\\AppData\\Local\\anaconda3\\envs\\isttc\\Lib\\site-packages\\abcTau') # IP: replaced previous line with that; relative path was not working
import abcTau

# %%
dataset_folder = 'E:\\work\\q_backup_06_03_2025\\projects\\isttc\\synthetic_dataset\\'
results_folder = 'D:\\intr_timescales\\abcTau_tests\\'

datasave_path = results_folder + 'synthetic_dataset_trials/'
# path and filename to save the intermediate results after running each step
inter_save_direc = results_folder + 'synthetic_dataset_trials/'

filenameSave = 'test'
inter_filename = 'abc_intermediate_results'

# %%
data_load = np.load(dataload_path + filename + '.npy')
print(data_load.shape)

plt.plot(data_load[0, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_load = np.load(dataload_path + filename + '.npy')
#       2 print(data_load.shape)
#       4 plt.plot(data_load[0, :])
#
# NameError: name 'dataload_path' is not defined

# %%
with open(dataset_folder + 'trials40.pkl','rb') as f:
    data = pickle.load(f)

# spike_trains = data['spike_trains']
alphas = data['alphas']
fr_values = data['fr_values']
taus_ms = data['tau_ms']
# duration_ms = data['duration_ms']

# print(f'n spike trains {len(spike_trains)}, len {spike_trains[0][-1]/1000}, duration_ms {duration_ms}')

# %%
data
# Out:
# {'trial_dict': {0: {0: [array([745, 815, 819, 838, 847, 849, 869, 872, 886, 905]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([30, 41, 93, 94]),
#     array([ 60, 517, 539, 539, 546, 562, 565, 568, 574, 595, 606, 637, 653,
#            703, 899, 909, 910, 923]),
#     array([967, 975, 975, 989]),
#     array([95]),
#     array([], dtype=int64),
#     array([242, 583, 733]),
#     array([ 97,  98, 113, 133, 152, 160, 174]),
#     array([], dtype=int64),
#     array([598]),
#     array([544]),
#     array([803]),
#     array([], dtype=int64),
#     array([760, 771, 779]),
#     array([ 14,  36,  36,  43,  59,  62,  65,  71,  92, 103, 134, 150, 200,
#            396, 406, 407, 420, 580, 818]),
#     array([332, 342, 344, 344, 375, 379, 388, 396, 452, 466, 473, 485, 489,
#            493, 495, 501, 520, 532, 546, 552, 561, 577, 577, 589, 592, 597,
#            774, 779, 931, 937]),
#     array([294, 871]),
#     array([619, 674, 675, 719]),
#     array([207, 800, 807]),
#     array([ 33,  80,  92, 103, 113, 118, 118, 136, 153, 155, 167, 171, 173,
#            199, 621]),
#     array([], dtype=int64),
#     array([915, 915, 933, 937, 949, 979, 984, 996]),
#     array([172, 194, 512, 537, 538, 981]),
#     array([], dtype=int64),
#     array([13, 17, 28, 31]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([17]),
#     array([125, 129, 132, 139, 168, 171, 174, 178, 182, 188, 205, 211, 220,
#            227, 227, 237, 237, 264, 279, 296, 726, 727, 742, 762, 781, 789,
#            803]),
#     array([ 44, 280, 290]),
#     array([], dtype=int64),
#     array([686, 692, 720, 729, 733, 738, 755, 777, 778, 784, 788, 789, 791,
#            796, 802, 825, 826, 858, 872, 933]),
#     array([], dtype=int64),
#     array([217, 229, 303]),
#     array([ 10,  21,  41,  54,  56,  58,  58,  60,  60,  66,  68,  84,  85,
#             96, 102, 118, 122, 129, 130, 133, 135, 158, 184, 215, 346, 408]),
#     array([  6,  10,  17, 421, 422, 437, 457, 490, 492, 493, 493, 517, 519,
#            520, 535, 537, 539, 540, 541, 541, 545, 550, 554, 558, 560, 561,
#            562, 564, 580, 597, 626, 639, 648, 650, 650, 652, 663, 666, 669,
#            674, 674, 678, 682, 683, 691, 693, 693, 696, 697, 700, 710, 713,
#            714, 714, 717, 720, 721, 721, 723, 726, 726, 729, 735, 736, 737,
#            740, 740, 742, 758, 762, 763, 764, 766, 768, 769, 773, 778, 780,
#            781, 782, 783, 785, 793, 815, 821, 825, 827, 831, 843, 849, 850,
#            850, 900]),
#     array([482]),
#     array([ 98, 232, 575, 580, 584, 594, 594, 601, 610, 614, 618, 620, 629,
#            639, 664, 665, 671, 722, 776, 803, 807, 812, 829, 923, 931, 984])]},
#   1: {0: [array([560, 589, 628, 629, 652, 654, 656, 668, 698, 712, 730, 746, 748,
#            754, 754, 765, 771, 773, 776, 781, 781, 782, 812, 820]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([92]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([104, 128, 295, 303, 311, 333, 336, 337, 340, 366, 367, 369, 370,
#            373, 375, 380, 382, 383, 394, 397, 399, 400, 403, 404, 410, 411,
#            416, 428, 428, 429, 430, 449, 464, 465, 465, 465, 467, 468, 473,
#            474, 482, 495, 499, 505, 508, 510, 513, 518]),
#     array([397, 402]),
#     array([123]),
#     array([8]),
#     array([], dtype=int64),
#     array([  2,  22,  28,  32,  33,  52,  57,  57,  62,  69,  70,  87, 114,
#            123, 216, 237, 302, 809, 840]),
#     array([472, 518, 525, 566, 571, 576]),
#     array([], dtype=int64),
#     array([416, 988]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([149, 171, 233, 250, 265, 276, 291, 314, 315, 332, 332, 337, 343]),
#     array([ 9, 14, 16, 17, 18, 22, 23, 26, 39, 40, 58, 72, 85, 89]),
#     array([241, 405]),
#     array([185, 194]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([6, 8]),
#     array([143, 143]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([258, 265, 267, 273]),
#     array([310, 326, 623, 626, 681, 916]),
#     array([], dtype=int64),
#     array([214, 257, 270, 275, 294, 296, 298, 301, 326, 357, 400, 412, 442,
#            462, 483, 539, 817]),
#     array([136, 172, 183, 187, 202, 206]),
#     array([], dtype=int64),
#     array([411]),
#     array([194, 216, 225, 237, 262, 269, 279, 279, 339]),
#     array([41]),
#     array([], dtype=int64)]},
#   2: {0: [array([226, 272, 373, 479, 486, 495, 569, 598]),
#     array([347, 572, 691]),
#     array([ 15,  49, 130, 217, 242, 245, 365, 489, 535, 758, 793, 827, 836,
#            885, 959]),
#     array([ 38, 199]),
#     array([122, 206, 648, 670, 686, 754, 945, 968]),
#     array([165, 365, 416, 437, 525, 530, 535, 542, 547, 613, 615, 724, 738,
#            743, 909, 918, 920, 993]),
#     array([  5,  35,  46,  56,  72,  75,  96, 132, 230, 310, 355, 446, 713,
#            813, 877]),
#     array([485, 533, 605, 606, 817]),
#     array([241, 259, 303, 351, 393, 466, 649, 750, 756, 763, 778, 790, 792,
#            813, 856, 871, 934]),
#     array([ 72, 872]),
#     array([ 4, 42]),
#     array([ 50,  63,  65,  96, 113, 200, 289, 331, 372, 432, 444, 453, 512,
#            550, 571, 573, 594, 597, 604, 656, 713, 729, 743]),
#     array([  3,  28, 129, 160, 226, 315, 345, 354, 359, 376, 392, 450, 578,
#            959]),
#     array([ 40,  93, 789, 845, 879]),
#     array([ 39,  70, 257, 462, 517, 590, 598, 655, 929, 982]),
#     array([  0,  38, 162, 319, 470, 744]),
#     array([144, 251, 260, 264, 272, 293, 314, 376, 446, 486, 648, 685, 863,
#            908]),
#     array([280, 350, 509, 514]),
#     array([100, 569, 696, 700]),
#     array([184, 195, 222, 225, 284, 321, 348, 387, 389, 391, 459, 481, 500,
#            521, 563, 575, 641, 647, 801, 847, 961, 993]),
#     array([292, 414, 664, 678, 683, 698, 705, 739, 772, 794, 870, 903]),
#     array([ 89, 116, 184, 194, 372, 789]),
#     array([163, 441, 458, 482, 524, 566, 597, 615, 636, 649, 657, 758, 782,
#            784, 822, 906, 948, 950, 988, 990]),
#     array([151, 309, 452, 474, 587, 598, 677, 767, 810, 875, 883, 890, 995]),
#     array([164, 217, 913, 969]),
#     array([309, 335, 351, 752, 883, 977]),
#     array([  0,  95, 126, 223]),
#     array([ 62, 197, 354, 406]),
#     array([243, 319, 366, 379, 521, 552, 555, 650, 682, 776, 914, 962]),
#     array([  5,  11,  57, 118, 243, 344, 393, 578, 641, 648, 800, 834, 941,
#            991]),
#     array([568, 828, 861]),
#     array([250, 504, 795, 865]),
#     array([ 46, 414, 499, 525, 657, 681, 704, 734, 760, 787, 821, 866, 887,
#            893, 911, 946, 968, 975, 979, 996]),
#     array([  1,  30,  68, 143, 187, 206, 212, 220, 223, 223, 244, 288, 305,
#            312, 326, 332, 443, 501, 504, 535, 539, 582, 594, 665, 675, 719,
#            727, 736, 868, 872]),
#     array([ 80,  86, 122, 150, 198, 283, 453]),
#     array([501, 780, 798, 809, 995]),
#     array([102, 479, 642]),
#     array([260, 302, 341, 555, 757, 961]),
#     array([ 13,  81, 252, 256, 431]),
#     array([439, 717, 734, 758, 800, 842, 873, 891, 912, 925, 933])]},
#   3: {0: [array([127, 181, 230, 297, 310, 329, 387, 551, 622, 633, 659, 731, 760]),
#     array([ 95, 202, 328, 504, 509, 522, 647, 862]),
#     array([ 25, 430, 488, 650, 656, 669, 977]),
#     array([ 24, 124, 217, 327, 329, 380, 421, 989]),
#     array([ 94, 862]),
#     array([ 25,  35, 376]),
#     array([215]),
#     array([ 45,  61, 233, 249, 433, 598, 607, 761]),
#     array([391, 471, 587, 622, 643, 671, 678, 720, 841, 871]),
#     array([101, 135, 373, 390, 398, 446, 601]),
#     array([975]),
#     array([ 90, 529, 552, 649, 662, 735, 742, 773, 782, 782, 847, 956]),
#     array([183, 216, 456, 585, 731]),
#     array([ 71, 646, 829]),
#     array([ 87, 167, 285, 313, 658, 903]),
#     array([ 53, 279, 389, 509]),
#     array([435, 467, 533, 898, 899]),
#     array([ 57, 229, 522, 618, 944]),
#     array([377, 388, 491, 856, 982]),
#     array([158, 417, 426, 747, 801, 995]),
#     array([279, 286, 311, 375, 623, 676, 793, 847, 898, 922]),
#     array([521, 689, 737, 790]),
#     array([ 32,  85, 114, 347, 456, 700, 763, 884]),
#     array([302, 563, 596, 631, 661, 701]),
#     array([ 31,  96, 746, 885, 886]),
#     array([651, 856, 894]),
#     array([242, 439, 477, 528, 795, 855, 918, 951, 981]),
#     array([ 27,  34,  76, 197, 227, 455, 520, 755, 971]),
#     array([293]),
#     array([ 50,  66,  91, 151, 209, 248, 392, 437, 466, 617, 672, 738, 846]),
#     array([  5,  34, 106, 156, 160, 166, 418, 502, 738, 787]),
#     array([ 49,  81, 276, 374, 690]),
#     array([ 32, 585, 832, 838, 954]),
#     array([ 12, 131, 352, 385, 554, 694, 797, 803]),
#     array([ 50,  69,  85, 112, 232, 252, 309, 355, 492, 514]),
#     array([216, 623, 625, 643, 709]),
#     array([103, 329, 439, 559]),
#     array([574, 759, 831]),
#     array([508, 512, 562, 591, 617, 620, 674, 882]),
#     array([245, 477, 575, 780, 785, 898, 942, 975])]},
#   4: {0: [array([535]),
#     array([215]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([123]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([134, 138, 229, 266, 282, 291, 313, 334, 363, 403, 407, 419, 699]),
#     array([856]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([779, 841]),
#     array([  3,  26,  35, 213, 380, 441, 486, 511, 524, 578, 595, 667, 688,
#            800, 817, 823, 824, 906, 920, 936, 974, 976, 979]),
#     array([], dtype=int64),
#     array([806, 842, 860, 889]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([584, 609]),
#     array([ 78, 103]),
#     array([85]),
#     array([], dtype=int64)]},
#   5: {0: [array([ 68, 111, 116, 143, 171, 292, 303, 304, 326, 458, 580, 595, 627,
#            647, 692, 739, 808, 887, 916, 926, 934, 957, 973]),
#     array([  7,  16,  35,  60,  62,  62,  83,  95, 116, 139, 153, 166, 187,
#            204, 207, 207, 220, 240, 241, 243, 284, 293, 311, 340, 385, 410,
#            413, 416, 425, 433, 439, 459, 463, 476, 491, 540, 638, 662, 664,
#            690, 714, 721, 778, 783]),
#     array([213, 703, 709, 870, 886, 913, 958, 998]),
#     array([272, 833, 916]),
#     array([169, 225, 277, 319, 373, 491, 532, 555, 591, 609, 627, 766]),
#     array([ 75, 133, 169, 584, 680]),
#     array([ 25,  27,  36,  36,  52,  53,  85, 290, 324, 335, 364, 401, 416,
#            796, 856, 886, 891, 999]),
#     array([585]),
#     array([ 27,  49,  71,  90, 237, 238, 829, 861, 862, 955]),
#     array([ 99, 171, 195, 201, 205, 223, 283]),
#     array([ 97, 139, 149, 561]),
#     array([  0,   3,  14,  65,  75,  89,  94, 113, 127, 139, 143, 841, 896]),
#     array([233, 269, 280, 283, 381, 924, 933]),
#     array([ 34,  57,  77, 121, 268, 852, 889, 957, 987]),
#     array([583, 740, 997]),
#     array([236, 268, 276, 277, 311, 332, 367, 680, 684, 764, 800, 865, 882,
#            884, 947]),
#     array([ 51, 116, 174, 776, 837, 867, 887]),
#     array([100, 184, 201, 342, 381, 472, 496, 501, 508, 522, 538, 543, 553,
#            573, 636, 686, 802, 828, 866, 874, 893, 944]),
#     array([173, 202, 205, 243, 254, 274, 280, 286, 381, 414, 427, 428, 434,
#            438, 475, 496, 503, 607, 633, 650, 654, 716, 744, 849, 853, 854,
#            922]),
#     array([307, 369, 392, 718, 742, 749, 840, 882, 887, 896, 973, 992]),
#     array([237, 243, 549, 567, 582, 588, 626, 637, 648, 652, 703, 811]),
#     array([214, 591, 616, 628]),
#     array([658, 674, 818, 821, 859, 879, 894, 914, 917, 978, 993, 994]),
#     array([144, 153, 214, 230, 268, 270, 274, 334, 353, 387, 422, 523, 531,
#            544, 556, 702, 708, 985, 995, 998]),
#     array([385, 390, 776, 824]),
#     array([288, 481, 526, 542, 584, 585, 589, 625, 691, 754, 758, 791, 802,
#            825, 829, 861, 890, 910]),
#     array([ 97, 172, 205, 220, 260, 298, 376, 399, 402, 480, 505, 596, 622,
#            695, 709, 716, 732, 879]),
#     array([ 32,  63, 132, 381, 381, 385, 444, 459, 473, 489, 534, 940, 963,
#            981]),
#     array([ 26, 282, 291, 308, 467, 490, 509, 528, 543, 557, 582, 626, 638,
#            646, 650, 650, 691, 832, 861, 998]),
#     array([110, 291, 561, 614, 767]),
#     array([305, 337, 427, 480, 585]),
#     array([458, 770, 852, 965, 971, 981]),
#     array([257, 309, 666, 691, 748, 755, 915, 969, 973]),
#     array([357, 483, 582]),
#     array([343, 392, 484]),
#     array([ 54, 110, 128, 223, 249, 251, 320, 323, 347, 351, 369, 379, 389,
#            674, 694, 727, 738]),
#     array([ 50,  87, 214, 233, 236, 241, 483, 501, 506, 518, 527, 579, 620,
#            626]),
#     array([559, 571, 576, 607, 867, 872, 878, 905, 916]),
#     array([ 92, 239, 252, 342, 578, 586, 641, 678, 732, 746, 779, 843]),
#     array([237, 275, 308, 322, 344, 381, 490, 522, 535, 551, 663, 670, 706,
#            750])]},
#   6: {0: [array([898, 910, 918, 948]),
#     array([862, 863, 873, 884]),
#     array([373, 373, 406, 442]),
#     array([248, 271, 276, 302, 735, 735, 748, 757, 770, 795, 819, 823, 826,
#            831, 845, 884]),
#     array([424]),
#     array([ 42,  50,  82, 103, 116, 127, 128, 664, 725, 760]),
#     array([499, 921]),
#     array([], dtype=int64),
#     array([ 85, 743, 754, 757, 775]),
#     array([958]),
#     array([472, 478, 487, 496]),
#     array([ 2, 37, 42, 87]),
#     array([365, 755]),
#     array([], dtype=int64),
#     array([664, 697, 711, 773, 799, 802, 808, 810, 818, 830, 839, 849, 853,
#            864, 894, 896, 915, 932, 949, 954, 956, 966, 968]),
#     array([292, 294, 303, 312, 314, 321, 331, 331, 334, 335, 337, 343, 353,
#            356, 357, 365, 365, 366, 369, 370, 392, 398, 407, 408, 415, 417,
#            421, 422, 425, 431, 434, 435, 437, 437, 437, 438, 439, 443, 444,
#            446, 446, 446, 451, 457, 460, 461, 461, 468, 474, 479, 499, 558,
#            603, 623, 629, 638, 647, 651, 651, 653, 656, 660, 678, 679, 679,
#            681, 681, 683, 684, 690, 694, 701, 702, 703, 705, 708, 708, 712,
#            712, 713, 716, 717, 717, 721, 726, 727, 727, 727, 729, 740, 750,
#            752, 757, 761, 768, 769, 771, 775, 786, 798, 841, 846, 897]),
#     array([31]),
#     array([206, 207, 472, 503, 535, 551, 581, 588, 792, 914, 947, 960]),
#     array([231, 270, 271, 493, 496, 516, 553, 557, 563, 595, 631, 632, 638,
#            651, 667, 669, 671, 678, 682, 701, 702, 705, 715, 715, 717, 719,
#            732]),
#     array([333, 718]),
#     array([ 54,  69, 902, 954]),
#     array([757, 758, 774]),
#     array([580]),
#     array([424, 427, 443, 471, 484, 492, 502, 504, 542, 665, 693]),
#     array([496, 570, 574, 586]),
#     array([229, 803, 816]),
#     array([], dtype=int64),
#     array([766, 773, 796, 826]),
#     array([845]),
#     array([199, 275, 545, 550, 574]),
#     array([], dtype=int64),
#     array([333, 341, 362, 369, 426]),
#     array([  0,  16,  24,  49,  60,  80,  97, 112, 176, 178, 185, 189, 703,
#            755]),
#     array([107, 806]),
#     array([375, 377, 381, 403, 860]),
#     array([309]),
#     array([], dtype=int64),
#     array([431, 485, 490, 496, 500, 508, 523, 524, 536, 544, 613, 673, 748,
#            749, 749, 752, 769, 774, 779, 826, 843]),
#     array([  1,  10,  11,  32,  50, 194, 710, 764, 769, 775, 779, 787, 802,
#            803, 815, 823, 892, 952]),
#     array([], dtype=int64)]},
#   7: {0: [array([370, 416, 445, 455, 480, 568, 584, 613, 643, 653, 673, 677, 701,
#            742, 779, 836, 874, 966, 980, 989]),
#     array([452, 481, 486, 492, 588, 594, 617, 624, 699, 711, 730, 771]),
#     array([ 16,  66, 608, 652, 659, 718, 803, 916, 951, 961, 972]),
#     array([374, 379]),
#     array([ 39, 106, 126, 137, 168, 180, 182, 240, 418, 436, 468]),
#     array([571, 629]),
#     array([832, 932]),
#     array([384, 392, 451, 496, 497, 541, 548, 551, 580, 623, 624, 643, 654,
#            661, 664, 681, 726, 755, 795, 804, 867, 872, 876, 910, 931, 935,
#            994]),
#     array([285]),
#     array([586, 619, 706, 739, 752, 753, 759, 765, 836, 851, 894, 915, 936]),
#     array([  0, 164, 183, 382, 461]),
#     array([ 51, 167, 172, 212, 225, 230, 245, 400, 451, 499, 701, 713, 722,
#            730, 748]),
#     array([737]),
#     array([ 12,  33, 584, 603, 604, 627, 708]),
#     array([804, 819, 838, 880, 897, 900, 909]),
#     array([ 34,  42,  44,  47,  48,  94, 103, 129, 144, 178, 181, 183, 227,
#            305, 315, 343, 353, 561, 561, 574, 581, 587, 611, 647, 652, 665,
#            678, 697, 734, 756, 761, 770, 776, 780, 803, 826, 841, 846, 846,
#            853, 855, 875, 888, 891, 896, 926]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([224, 875]),
#     array([132, 511]),
#     array([ 31, 113, 132, 149, 194, 206, 222]),
#     array([510, 793, 796, 804, 851, 891, 900, 906, 978, 979, 987]),
#     array([799, 801, 820, 820, 843, 871, 921, 926, 939, 945, 947, 947, 957,
#            960, 977, 988, 993, 995, 998, 999]),
#     array([854, 870]),
#     array([ 25,  28,  42,  75,  77,  89,  97, 105, 128, 158, 159, 176, 179,
#            191, 192, 194, 196, 211, 213, 218, 224, 226, 226, 227, 234, 235,
#            239, 240, 246, 249, 253, 253, 256, 264, 270, 273, 280, 294, 296,
#            297, 300, 301, 311, 323, 325, 326, 330, 352, 352, 354, 360, 361,
#            361, 366, 367, 371, 372, 377, 394, 403, 421, 436, 438, 439, 451,
#            452, 461, 478, 480, 488, 533, 533, 546, 608, 727, 737, 746, 753,
#            795, 807, 824]),
#     array([122, 206, 259, 275, 277, 293, 296, 296, 302, 322]),
#     array([541, 574, 607, 626, 691, 723, 845]),
#     array([865]),
#     array([ 24,  50,  51, 117, 149, 150, 172, 352, 369]),
#     array([443, 463, 597, 621, 626, 649, 650, 713, 728, 770, 787, 790, 814,
#            826, 836, 853, 888, 923, 943, 995]),
#     array([532, 591, 612, 630, 633, 653, 734, 743, 754, 859, 914]),
#     array([788, 797, 882, 951, 953, 960, 984, 985, 994]),
#     array([240, 419, 455, 464, 505, 612, 615, 620, 638, 650, 669, 669, 679,
#            682, 688, 689, 704, 739, 772, 780, 987]),
#     array([216, 220, 239, 250, 257, 278, 310, 323, 351, 357, 366, 377, 385,
#            386, 392, 396, 454, 460, 475, 479, 506, 519, 536, 553, 571, 574,
#            587, 596, 616, 630, 638, 639, 640, 651, 688, 708, 713, 734, 751,
#            756, 871]),
#     array([52]),
#     array([432, 535]),
#     array([], dtype=int64),
#     array([480]),
#     array([ 45,  83,  84, 109, 118, 118, 188, 276, 305, 345, 361, 391, 528,
#            540]),
#     array([949, 972])]},
#   8: {0: [array([143]),
#     array([394, 888]),
#     array([303, 756]),
#     array([146]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([21]),
#     array([172, 316]),
#     array([183]),
#     array([], dtype=int64),
#     array([685, 759]),
#     array([519]),
#     array([216]),
#     array([512, 605]),
#     array([], dtype=int64),
#     array([922]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([222, 307, 473]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([ 74, 938]),
#     array([ 20, 130, 235, 300, 329]),
#     array([778]),
#     array([888, 903]),
#     array([398]),
#     array([], dtype=int64),
#     array([373, 386, 777]),
#     array([], dtype=int64),
#     array([ 53,  66, 866]),
#     array([209]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([887, 905, 990]),
#     array([ 62, 522]),
#     array([ 67, 379])]},
#   9: {0: [array([815, 830, 920, 931]),
#     array([ 80, 129, 210, 223, 423, 424, 442]),
#     array([396]),
#     array([118, 227, 480, 486, 502, 550, 839, 915]),
#     array([272, 317, 364, 374, 384, 388, 452, 542, 576]),
#     array([ 39, 129, 201, 211, 338, 909]),
#     array([68]),
#     array([526, 808, 816, 840, 842]),
#     array([305, 512]),
#     array([905]),
#     array([], dtype=int64),
#     array([691, 786]),
#     array([441, 448, 509, 618, 641, 805, 817, 823, 829, 844, 846, 847, 911,
#            941, 949, 969, 970, 971]),
#     array([3]),
#     array([822]),
#     array([842, 882]),
#     array([  7, 769, 812, 822, 829, 835, 851, 854, 893, 897, 921, 922, 923,
#            949]),
#     array([623, 744]),
#     array([620, 711]),
#     array([224, 292, 348, 833, 979]),
#     array([963]),
#     array([], dtype=int64),
#     array([ 49, 140, 790, 927]),
#     array([257, 379, 685]),
#     array([507, 911]),
#     array([388, 439, 552, 662, 892, 964]),
#     array([513]),
#     array([ 45, 210, 220, 365, 418, 419, 426, 504, 744]),
#     array([100, 144, 609, 630]),
#     array([ 56,  81, 139, 148, 162, 249, 255, 293, 391, 601, 646, 783]),
#     array([], dtype=int64),
#     array([ 52, 149]),
#     array([], dtype=int64),
#     array([ 53, 200, 231, 244, 692, 762, 859, 940]),
#     array([355, 380, 396, 407, 412, 472, 476, 486, 534, 539]),
#     array([284, 519, 578, 650, 681, 691, 951]),
#     array([ 76,  86, 171, 171, 189, 190, 223, 230, 234, 263, 333, 433, 451,
#            460, 484, 485, 592, 604, 634, 639, 689, 723, 747, 752, 806, 906,
#            971]),
#     array([437, 474, 534, 557, 602, 771, 824, 897]),
#     array([ 33,  92, 103, 185, 193, 459, 565, 659]),
#     array([ 40,  80, 435, 469, 629, 708, 719, 722])]},
#   10: {0: [array([109, 476, 726]),
#     array([403, 858]),
#     array([], dtype=int64),
#     array([181, 675]),
#     array([726, 774, 814, 820, 894, 911, 929, 951, 972]),
#     array([467, 472, 527, 577, 590]),
#     array([156, 276, 560, 628, 906, 968]),
#     array([233, 251, 528]),
#     array([160, 204, 337]),
#     array([790, 800]),
#     array([], dtype=int64),
#     array([236, 576, 670]),
#     array([232, 239, 689, 826, 851, 869, 995]),
#     array([], dtype=int64),
#     array([343, 586, 601]),
#     array([277, 292, 361, 397, 419, 465, 511, 511, 620, 996]),
#     array([632, 655, 718, 724, 775, 782, 811, 926, 963, 998]),
#     array([577]),
#     array([230, 329]),
#     array([ 11, 103, 199, 311, 326, 401, 641, 953, 989, 992, 996]),
#     array([786, 943]),
#     array([633]),
#     array([672]),
#     array([163]),
#     array([], dtype=int64),
#     array([ 25, 356, 592]),
#     array([803]),
#     array([  3, 188, 812, 879]),
#     array([], dtype=int64),
#     array([477, 498, 503, 531, 536, 562, 619, 621, 624, 635, 674, 692, 911]),
#     array([202, 414]),
#     array([315, 570, 597, 648, 736, 899, 916]),
#     array([453, 513, 592, 631, 635, 836, 941, 981]),
#     array([ 12,  14, 363, 425, 989]),
#     array([130, 529]),
#     array([870]),
#     array([], dtype=int64),
#     array([594, 797]),
#     array([559, 657]),
#     array([785])]},
#   11: {0: [array([554, 566, 572, 573, 582, 601]),
#     array([], dtype=int64),
#     array([ 53,  57, 380, 382, 383, 389, 395, 397, 399, 399, 400, 401, 401,
#            402, 409, 410, 410, 411, 412, 414, 414, 417, 417, 419, 419, 419,
#            421, 424, 425, 426, 427, 428, 430, 432, 432, 433, 435, 439, 442,
#            444, 444, 445, 445, 446, 448, 450, 451, 455, 455, 456, 457, 463,
#            465, 466, 471, 472, 473, 473, 478, 483, 484, 489, 493, 515]),
#     array([770]),
#     array([543, 546, 553]),
#     array([196, 866, 901]),
#     array([919]),
#     array([ 65,  70, 275, 353, 353, 358, 358, 383, 398, 398, 400, 401, 404,
#            404, 405, 405, 406, 409, 410, 414, 415, 417, 417, 419, 420, 420,
#            421, 421, 422, 423, 423, 423, 424, 425, 427, 427, 428, 430, 432,
#            432, 434, 435, 436, 436, 437, 438, 440, 445, 446, 446, 448, 449,
#            450, 454, 456, 457, 458, 458, 461, 465, 469, 471, 474, 481, 481,
#            483, 486, 491, 500, 520, 521, 523, 524, 528, 529, 531, 533, 535,
#            537, 538, 539, 547, 548, 554, 570, 571, 571, 572, 575, 578, 580,
#            583, 596]),
#     array([155, 613, 649, 652, 656, 657, 658, 661, 669, 694, 699]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([77]),
#     array([462, 481, 483, 483]),
#     array([ 59,  61,  73,  76,  76,  85,  94, 102, 648, 652, 665, 666]),
#     array([235]),
#     array([138]),
#     array([], dtype=int64),
#     array([878, 879]),
#     array([138, 145]),
#     array([207, 208, 500, 513, 515]),
#     array([  4, 428, 442, 652, 657, 660, 662, 675, 695, 726]),
#     array([], dtype=int64),
#     array([621, 628]),
#     array([], dtype=int64),
#     array([ 9, 10, 17, 24, 26, 31]),
#     array([252, 754, 761, 762, 767, 768, 788, 798, 803, 804, 809, 811, 817,
#            826, 833, 833, 835, 839, 840, 840, 841, 847, 848, 848, 853, 857,
#            864, 866, 866, 866, 872, 876, 879, 879, 879, 880, 884, 889, 891,
#            893, 896, 899, 900, 909, 909, 910, 911, 914]),
#     array([132, 146, 564, 826, 828, 828, 830, 839, 840, 840]),
#     array([873, 875, 886, 893, 896, 966]),
#     array([678]),
#     array([123, 134, 134, 137, 406, 409, 419, 440, 443, 447, 448, 449, 450,
#            452, 454, 454, 458, 461, 469, 472, 474, 479, 483, 492, 503, 504,
#            504, 771]),
#     array([462, 464, 482, 486, 490, 495, 497, 501, 507, 514, 516, 527]),
#     array([368]),
#     array([758]),
#     array([313, 499, 503, 504, 505]),
#     array([301, 306, 643, 664, 690, 691, 700]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([423])]},
#   12: {0: [array([ 54,  67,  97, 250, 288, 320, 369, 431, 474]),
#     array([127, 252, 274, 317, 318, 356, 382, 401, 634, 676, 690]),
#     array([279, 708, 845, 873, 915]),
#     array([170, 253, 341, 348, 354, 360, 388, 433, 782, 812, 915]),
#     array([44, 81]),
#     array([  3, 399, 519, 521, 687, 909]),
#     array([  3, 137, 183, 822, 903]),
#     array([163, 325, 330, 435, 812]),
#     array([  4, 182, 188, 495, 565, 608, 611, 680, 747]),
#     array([ 99, 784]),
#     array([ 55,  91, 112, 153, 175, 189, 637, 693, 697, 705, 727, 829, 844,
#            879, 906, 940]),
#     array([133, 179, 240, 245, 711]),
#     array([981]),
#     array([618, 987]),
#     array([243, 258, 430, 602, 633, 727, 812, 873, 910]),
#     array([319, 326, 488, 662, 701]),
#     array([452, 460, 540, 554, 792, 834]),
#     array([ 62,  75, 133, 141, 379, 698, 703, 808, 887]),
#     array([ 54,  73, 255, 279, 318, 331, 333, 374, 403, 690, 702, 775, 851,
#            930, 958]),
#     array([ 67, 112, 161, 432, 685, 728, 783, 887]),
#     array([185, 343, 591, 937]),
#     array([165, 980]),
#     array([179, 586, 668, 912, 925]),
#     array([101, 114, 541, 578, 820]),
#     array([ 86, 548, 567, 584, 660, 726, 996]),
#     array([115, 132, 134, 256, 283, 652, 812, 926]),
#     array([143, 384, 446, 680, 760]),
#     array([174, 293, 376, 377, 393, 435, 518, 544, 587, 603, 741]),
#     array([253, 266, 301, 328, 371, 417, 428, 438, 439, 441, 446, 502, 538,
#            557, 593, 665, 819, 845]),
#     array([ 87, 271, 273, 752, 829, 898, 947]),
#     array([ 81, 112, 146, 154, 218, 219, 224, 440, 694, 726]),
#     array([], dtype=int64),
#     array([283, 668, 838]),
#     array([158, 178, 186, 258, 422, 471]),
#     array([ 15,  26, 128, 271, 328, 351, 493, 616, 797, 822, 908, 989]),
#     array([235, 236, 364, 434, 484, 697, 829, 868, 918, 925]),
#     array([  0, 459, 550]),
#     array([239, 646, 808, 923]),
#     array([431, 476, 554, 577, 661, 840, 929, 938]),
#     array([ 75, 302, 338, 359, 400, 422, 436, 884, 940, 944, 952, 974])]},
#   13: {0: [array([350, 441, 479, 834]),
#     array([391, 427, 429, 704, 741, 790, 867, 955]),
#     array([  6, 179, 272, 353, 405, 578, 722]),
#     array([106, 176, 257, 274, 500, 554, 588, 660, 900]),
#     array([271, 638, 672, 708]),
#     array([142, 213, 216, 290, 889]),
#     array([326, 553, 853, 927]),
#     array([111, 296, 357, 516, 539, 631, 675, 868, 885, 992]),
#     array([132, 210, 388, 663, 802, 839, 918, 940]),
#     array([104, 197, 437, 898]),
#     array([  8, 136, 172, 289, 625, 676, 873, 894]),
#     array([414, 585, 998]),
#     array([  5,  62, 160, 545, 674, 779, 784, 857, 971]),
#     array([167, 215, 424, 539, 656, 694, 703, 744, 749, 870, 872, 965]),
#     array([ 45, 191, 899, 923]),
#     array([116, 159, 294, 595, 758, 935, 979]),
#     array([216, 275, 297, 316, 666, 703]),
#     array([196, 378, 499, 598, 615, 638, 644, 709, 766]),
#     array([ 65, 125, 281, 589, 624, 714, 808, 914]),
#     array([120, 261, 402, 417, 589]),
#     array([305, 465, 532, 545, 688]),
#     array([  5, 231, 493, 912]),
#     array([  0, 485, 535, 568, 573, 671, 704, 722, 796, 927]),
#     array([ 23, 121, 127, 142, 205, 219, 252, 272, 313, 370, 599, 642]),
#     array([145, 186, 441, 465, 492, 868, 976]),
#     array([247, 282]),
#     array([176, 276, 382, 499, 580, 603, 606, 639, 664, 696, 866, 991, 994]),
#     array([478, 521, 646, 648, 719, 888, 908, 963]),
#     array([ 41,  73, 472, 621, 749, 787, 862, 897]),
#     array([ 64,  79, 107, 224, 263, 310, 379, 403, 482, 584, 602, 603]),
#     array([134, 226, 447, 809, 813, 815, 841, 935, 943]),
#     array([ 25, 259, 416, 454, 562, 698, 732]),
#     array([129, 355, 487, 881]),
#     array([152, 211, 269, 306, 573]),
#     array([178, 191, 256, 338, 553]),
#     array([ 50,  72,  91,  97, 443, 524, 573, 581, 586, 605, 644, 672, 792,
#            834, 878]),
#     array([ 81, 363, 436, 444, 497, 524, 560, 616, 619, 641, 977]),
#     array([294, 443, 526, 944]),
#     array([129, 296, 333, 420, 542, 586, 731, 962]),
#     array([ 12, 124, 324, 350, 414, 460, 472, 520, 725, 729, 830, 898])]},
#   14: {0: [array([ 90, 132, 161, 331, 447, 479, 490, 492, 493, 501, 522, 543, 641]),
#     array([836]),
#     array([114, 161, 190, 257, 367, 375, 393, 498, 523, 567]),
#     array([ 62,  71, 237, 245, 261, 273, 573, 650]),
#     array([996]),
#     array([640, 660, 681, 800, 947]),
#     array([306, 327, 562, 633, 776, 791, 902]),
#     array([388]),
#     array([166, 197, 215, 471, 481, 504]),
#     array([138, 252, 313, 381, 488, 647]),
#     array([487, 638, 899, 952, 955]),
#     array([ 36, 939]),
#     array([ 11,  58,  86, 171, 287, 310, 483, 720, 765]),
#     array([504]),
#     array([523, 544]),
#     array([440, 668, 677, 903]),
#     array([ 31,  78, 106, 191, 307, 330, 503, 740, 785]),
#     array([220, 456, 636, 647, 867, 975]),
#     array([  8,  81, 318, 668, 815]),
#     array([367, 911, 960]),
#     array([112, 511]),
#     array([112, 415]),
#     array([143, 281, 494, 616, 692, 702, 886]),
#     array([282]),
#     array([ 13,  51, 235, 288, 647, 912]),
#     array([ 50, 208, 498]),
#     array([], dtype=int64),
#     array([ 88, 112, 114]),
#     array([342]),
#     array([151, 161]),
#     array([195, 215, 541, 627]),
#     array([685]),
#     array([149, 169, 190, 309, 456, 681, 731, 756, 759, 859, 962]),
#     array([398, 626, 689, 822]),
#     array([834, 968]),
#     array([240, 318, 330, 675, 788, 953]),
#     array([348, 748]),
#     array([487, 500, 513, 830, 862, 941]),
#     array([  9,  40,  70, 138, 146, 272, 451, 579, 710]),
#     array([786, 861])]},
#   15: {0: [array([508, 994]),
#     array([], dtype=int64),
#     array([ 54,  63, 799]),
#     array([], dtype=int64),
#     array([136, 681]),
#     array([672, 974]),
#     array([], dtype=int64),
#     array([664]),
#     array([ 29,  46,  62, 108, 128, 136, 272, 710]),
#     array([386, 802, 871, 961, 980]),
#     array([348, 413, 854]),
#     array([ 74, 596, 911]),
#     array([ 62,  95, 167, 248, 475, 476]),
#     array([ 23,  45, 274, 950]),
#     array([192, 208, 246, 255, 266, 287, 312, 324, 325, 616, 665]),
#     array([387, 395]),
#     array([103, 166, 337, 846, 884, 951]),
#     array([353, 892]),
#     array([], dtype=int64),
#     array([ 84, 135, 156, 165, 695, 928]),
#     array([], dtype=int64),
#     array([433, 718, 734]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([215, 432, 813]),
#     array([166, 316, 348, 650]),
#     array([528]),
#     array([], dtype=int64),
#     array([532]),
#     array([], dtype=int64),
#     array([ 68,  99, 673]),
#     array([832]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([171, 190, 330, 478, 769]),
#     array([956]),
#     array([656]),
#     array([698, 733, 736]),
#     array([700]),
#     array([414, 420, 452, 465, 517, 556, 568, 654])]},
#   16: {0: [array([ 25,  86, 162, 171, 200, 451, 513, 530, 559, 607, 721]),
#     array([289, 317, 342, 654, 943]),
#     array([ 65,  66, 359, 579, 661, 874]),
#     array([126, 159, 482, 564, 704, 899]),
#     array([461, 651, 690, 702, 913]),
#     array([167, 243, 510, 850]),
#     array([ 69, 175, 522, 686, 720, 775]),
#     array([337, 470, 487, 562, 582, 880, 928]),
#     array([ 16, 436, 438, 575, 692, 763, 779, 910]),
#     array([472, 616]),
#     array([360, 401, 731, 973]),
#     array([189, 658, 671, 688, 735, 926]),
#     array([145, 356, 593, 748, 935, 977]),
#     array([ 16, 120, 328, 526, 534, 591, 687]),
#     array([276, 562]),
#     array([282, 798, 858, 987]),
#     array([234, 334, 601, 658, 682, 732, 739, 907]),
#     array([396, 430, 877]),
#     array([127, 260, 346, 371, 632, 695]),
#     array([606]),
#     array([246, 320, 386, 467, 522, 545, 609, 944]),
#     array([136, 580, 622, 807, 819]),
#     array([156, 198, 383, 395, 757, 817, 819]),
#     array([176, 324, 338, 364]),
#     array([319]),
#     array([109, 143, 203, 232, 264, 397, 419, 495, 684, 877, 953]),
#     array([314, 433, 595, 638, 845, 867]),
#     array([392, 454, 550, 604, 622, 947]),
#     array([261, 299, 340, 513]),
#     array([156, 185, 280, 330, 416, 932]),
#     array([ 23,  99, 324, 396, 443, 480, 733, 973]),
#     array([ 65, 481, 542, 569]),
#     array([  2,  15, 219, 252, 288, 411, 425, 559, 705, 750, 801, 806, 847,
#            874, 907]),
#     array([ 94, 225, 360, 507]),
#     array([ 85, 254, 740, 892, 920, 927]),
#     array([313, 358, 534, 538, 755, 973]),
#     array([201, 378, 460, 538]),
#     array([613, 701, 750, 874, 915]),
#     array([154, 164, 225, 265, 683]),
#     array([312, 538, 571, 756, 784, 861])]},
#   17: {0: [array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([939, 939]),
#     array([], dtype=int64),
#     array([579]),
#     array([865]),
#     array([], dtype=int64),
#     array([614, 660, 667, 692, 698, 705, 705, 727, 760, 775, 801, 824, 826,
#            841, 884]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([755]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64)]},
#   18: {0: [array([154, 183, 190, 194, 211, 228, 241, 246, 257, 260, 266, 277, 316]),
#     array([657, 660, 865]),
#     array([], dtype=int64),
#     array([412, 465, 472, 488, 518, 566, 575, 581, 621, 671, 699, 764, 888,
#            899]),
#     array([153, 154, 165, 182, 216, 724, 793, 833, 936, 948, 969]),
#     array([ 20, 222, 293, 371, 375, 401, 429, 479, 774, 842]),
#     array([259, 276]),
#     array([124, 222, 362, 403, 406, 417, 464, 474, 577, 682, 739]),
#     array([188, 441, 573]),
#     array([177, 624, 756, 900, 934]),
#     array([  7,  52, 625]),
#     array([ 17, 247, 340, 519]),
#     array([  1,  12, 302, 330, 395, 479, 480, 567, 587, 636, 653, 688, 940,
#            947, 956, 968, 997]),
#     array([ 12,  43, 642]),
#     array([ 39, 271, 369, 509, 550, 553, 564, 611, 621, 724, 829, 886]),
#     array([502, 572, 850]),
#     array([154, 242, 295, 457, 477, 613, 664, 681, 681, 689]),
#     array([ 31, 175, 209, 480, 502, 535, 644]),
#     array([], dtype=int64),
#     array([374]),
#     array([278, 313, 335, 398, 625, 673, 686]),
#     array([ 16,  94, 270, 270, 379, 399, 426, 546, 552, 555, 683, 799, 830,
#            873]),
#     array([472, 549]),
#     array([354, 464, 469, 474, 526, 555, 566, 577, 579, 580, 601, 610, 660,
#            679, 693]),
#     array([], dtype=int64),
#     array([ 80, 192, 223, 602]),
#     array([649, 718, 754, 760, 805, 837, 839, 901, 909, 929, 930, 938, 964]),
#     array([ 17, 125, 208, 981]),
#     array([ 39, 341, 394, 405, 514, 646, 701, 752, 758, 762, 856, 918]),
#     array([ 37,  60, 101, 112, 112, 122, 155, 186, 264, 269, 284, 333, 363,
#            401, 429, 485, 589, 591, 603, 664, 722, 822, 933, 979]),
#     array([314, 543, 873, 901, 919, 939, 947, 993]),
#     array([241, 274, 297, 325, 367, 380, 458, 466, 483, 514, 531, 660, 706,
#            734, 739, 744, 796, 811, 831]),
#     array([ 34,  39,  43, 116, 600, 665, 674, 687]),
#     array([114, 703, 786, 834, 871, 918, 954, 988]),
#     array([424, 501, 680, 684, 685, 706, 717, 753, 812, 813, 847, 897, 975]),
#     array([354, 370, 708, 995, 997]),
#     array([143, 383, 386, 405]),
#     array([], dtype=int64),
#     array([127, 128, 133, 143, 144, 146, 295, 304, 344, 345, 398, 407, 428,
#            437, 465, 572, 651, 929, 954, 967, 977]),
#     array([ 12,  14,  16,  29, 101, 189, 250, 273])]},
#   19: {0: [array([142, 649, 710]),
#     array([ 24, 131, 134, 185, 225, 258, 702, 744, 823, 832, 848]),
#     array([116, 210, 566, 611, 927, 939, 939, 972]),
#     array([ 55, 256, 301, 302, 828]),
#     array([371, 406, 493, 590, 675, 806, 886]),
#     array([173, 649, 916, 962]),
#     array([ 57, 403, 404, 408, 465, 536, 655, 687]),
#     array([337, 708, 873, 905, 944]),
#     array([ 54, 287, 296, 914, 924]),
#     array([198, 231, 403, 415, 964]),
#     array([ 49, 303, 359, 459, 641, 702]),
#     array([159, 172, 216, 532, 742, 824, 846, 847, 931]),
#     array([ 13,  61, 180, 234, 270, 332, 409, 713, 804]),
#     array([ 46,  89,  96, 707, 923, 980]),
#     array([ 30,  47,  54, 223, 405, 537, 660, 705, 783]),
#     array([146, 191, 192, 718]),
#     array([ 38,  58, 173, 392, 507, 555]),
#     array([117, 461, 551, 653, 839]),
#     array([245, 315, 336, 479, 637, 696, 884, 954]),
#     array([444, 779, 995]),
#     array([367, 492, 623, 846, 875, 955]),
#     array([ 89, 368, 406, 894, 944]),
#     array([ 27, 255, 743, 886, 937, 974, 986]),
#     array([240, 354, 450, 499, 605, 627, 660, 962]),
#     array([290, 560, 571, 635, 780, 958, 959]),
#     array([ 89, 268, 336, 443, 602, 606, 623]),
#     array([510, 716]),
#     array([206, 685, 899, 907]),
#     array([], dtype=int64),
#     array([332, 541, 616, 906, 964]),
#     array([ 39, 583, 972, 983]),
#     array([ 95, 194, 348, 352, 747, 872, 933]),
#     array([325, 429, 455, 634, 660, 897, 986, 996]),
#     array([228, 233, 286, 340, 378, 421, 452, 933]),
#     array([ 85, 258, 489, 620, 780, 797, 827, 874, 903, 952]),
#     array([124, 177, 654, 977]),
#     array([283, 408, 539, 762, 791, 871]),
#     array([115, 423]),
#     array([168, 689, 820, 998]),
#     array([ 49, 156, 749, 992])]},
#   20: {0: [array([255]),
#     array([ 37,  86,  89, 366, 378, 409, 473, 519, 691, 845]),
#     array([210, 235, 252, 252, 332, 349, 446, 512, 551, 564, 565, 568, 574,
#            585, 587, 593, 617, 668, 922]),
#     array([221, 821]),
#     array([ 65, 631, 661, 703, 709, 721, 766]),
#     array([ 13, 332, 432, 538, 898]),
#     array([122, 292, 344, 514, 834]),
#     array([526, 672, 729, 763, 923, 988]),
#     array([135, 447]),
#     array([192, 223, 737, 815]),
#     array([ 70,  80, 577, 620, 632, 725]),
#     array([  6,  91, 159, 268, 341, 397, 413, 419, 517, 549, 661, 662, 664,
#            681, 857]),
#     array([177, 240, 283, 862]),
#     array([ 93, 373, 568, 649, 768, 770]),
#     array([ 69, 110, 138, 196, 253, 537, 564, 668, 695, 731, 735, 797, 954]),
#     array([ 98, 150, 275, 553, 628, 633, 718, 730, 984]),
#     array([499, 560, 578, 602, 787, 819, 829, 963]),
#     array([257, 306, 442, 452, 713, 716, 721, 769, 774, 810]),
#     array([121, 382, 414, 596, 610, 614, 635, 805, 830, 842]),
#     array([108, 191, 824, 907, 914]),
#     array([125, 127, 289, 330, 399, 717, 843]),
#     array([ 95, 176, 244, 310, 316, 700]),
#     array([197, 260, 397, 440, 461, 488, 551, 587, 711]),
#     array([744, 962]),
#     array([402, 564, 695]),
#     array([153, 210, 229, 346, 427, 430, 536, 537, 550, 605, 804, 969]),
#     array([  6, 102, 129, 446, 538, 543, 871]),
#     array([ 37,  93, 261, 293, 338]),
#     array([  5, 525, 849, 960]),
#     array([272, 432, 565, 981]),
#     array([ 69, 319, 449, 719, 722, 804, 848, 889]),
#     array([202, 236, 359, 393, 438, 492, 499, 506, 588, 642, 763, 767, 824]),
#     array([189, 539, 612, 663]),
#     array([ 19,  24, 112, 322, 471, 575, 601, 630, 713, 733, 970]),
#     array([ 33,  56, 188, 200, 399, 424, 505, 750, 982]),
#     array([128, 192, 215, 347, 359, 558, 583, 664, 909]),
#     array([ 47, 141, 372, 537, 580, 670]),
#     array([199, 431, 453, 545, 930]),
#     array([ 45, 120, 134, 140, 147, 155]),
#     array([105, 549, 709, 842])]},
#   21: {0: [array([987]),
#     array([205, 396, 862]),
#     array([], dtype=int64),
#     array([375]),
#     array([292, 548]),
#     array([137, 615, 905, 984]),
#     array([461, 503, 513, 550, 813]),
#     array([872, 889, 950, 997]),
#     array([ 84, 751]),
#     array([ 98, 851]),
#     array([388, 422, 825]),
#     array([ 80, 111, 246, 307, 334, 623, 641, 691, 723, 926]),
#     array([131, 623, 946]),
#     array([112, 506, 656]),
#     array([290, 705]),
#     array([109, 386, 388]),
#     array([229, 578]),
#     array([ 64, 101, 206, 719, 729]),
#     array([282, 301, 574, 774, 827, 901, 902, 917, 965]),
#     array([  2,  16, 219, 289, 363]),
#     array([244, 368, 459, 694, 809, 895]),
#     array([349, 743, 793, 810, 839, 877, 970, 989]),
#     array([677, 712]),
#     array([487, 906]),
#     array([223, 291, 374]),
#     array([165, 342]),
#     array([501, 836]),
#     array([968]),
#     array([ 61, 138, 162, 200, 242, 519, 538, 657, 659, 841]),
#     array([173, 277, 471]),
#     array([ 19, 508, 622, 859]),
#     array([166, 883]),
#     array([618]),
#     array([591]),
#     array([ 70, 128, 246, 301, 766, 768]),
#     array([107, 133, 177, 222, 228, 228, 386]),
#     array([655, 668, 710, 741, 814]),
#     array([ 35,  37, 505, 787, 805]),
#     array([], dtype=int64),
#     array([164, 740, 884])]},
#   22: {0: [array([], dtype=int64),
#     array([594, 770, 819, 846, 850, 854, 867, 880, 963]),
#     array([100, 122, 344, 365, 390, 431, 636, 645, 683, 688, 698]),
#     array([ 84, 720, 731, 769, 770, 804, 839, 841]),
#     array([ 47,  55, 128, 372, 385, 401, 519, 714, 743, 787, 802]),
#     array([848, 855, 859, 862, 875, 911, 983]),
#     array([ 26,  58, 677, 680, 684, 742, 799, 845, 857, 872, 877, 896, 916]),
#     array([], dtype=int64),
#     array([808, 810, 818, 833]),
#     array([ 37,  58, 312, 692, 707]),
#     array([410, 516, 813]),
#     array([], dtype=int64),
#     array([ 58,  59,  87, 211]),
#     array([483, 508, 525, 547, 556, 570, 794, 811, 817, 983]),
#     array([ 62, 685, 718, 807]),
#     array([ 15,  54,  62,  87, 104, 108, 112, 112, 120, 138, 228, 234, 272,
#            319, 352, 504, 659, 670, 670, 674, 935, 946, 953, 988]),
#     array([431, 433, 461, 489]),
#     array([602]),
#     array([  7,  14,  20,  33,  46,  50,  56,  58, 116, 128, 133, 153, 154,
#            182]),
#     array([330, 559, 570, 581, 775, 806]),
#     array([827, 836]),
#     array([ 45, 307, 346, 371]),
#     array([322, 922]),
#     array([], dtype=int64),
#     array([379, 409, 452, 464, 492, 504, 516, 529, 538, 540, 568, 569, 575,
#            592, 594, 672]),
#     array([84]),
#     array([174, 206, 207, 223, 258, 948]),
#     array([ 11, 701]),
#     array([531, 571]),
#     array([210, 417, 780]),
#     array([ 35,  37, 460, 481, 487, 493, 525, 533, 565, 589, 624, 675, 764]),
#     array([103, 167, 192, 363, 664, 992, 998]),
#     array([226, 297, 338, 350, 430]),
#     array([ 43,  65,  82,  89,  92, 137, 386, 395, 430, 466]),
#     array([], dtype=int64),
#     array([120, 123, 152, 158, 189, 348, 359, 365, 383, 406, 408, 416, 478,
#            479]),
#     array([375]),
#     array([724]),
#     array([481]),
#     array([343, 353, 899, 927, 955, 964, 972, 977, 982])]},
#   23: {0: [array([  6, 231, 272, 346, 352, 437, 461, 465, 465, 491, 559, 577, 582,
#            599, 603, 609, 653, 715, 809, 857]),
#     array([196, 672, 827, 852, 867, 982]),
#     array([143, 156, 224, 264, 463, 543]),
#     array([174, 264, 428, 457, 478, 480, 494, 503, 574, 619, 634, 693, 695]),
#     array([104, 755, 762, 801]),
#     array([779, 808, 817, 829, 830, 875, 899, 935, 936, 949, 955]),
#     array([293, 375, 470, 536, 555, 591, 593, 595, 614, 616, 758]),
#     array([ 88,  88,  98, 119, 411]),
#     array([220, 243, 298, 308, 413, 429, 717]),
#     array([ 20,  27,  43, 107, 320]),
#     array([122, 773, 780, 819]),
#     array([ 14,  35, 112, 133, 143, 146, 185, 241, 266, 453]),
#     array([192, 405, 768]),
#     array([467, 514, 554, 583, 774]),
#     array([168, 235, 350, 350, 362, 386, 402, 407, 416, 417, 418, 425, 611]),
#     array([174, 317, 389, 394, 807, 877, 886]),
#     array([ 55,  64,  84, 111, 594, 682, 728, 758, 791, 826]),
#     array([ 53,  92,  94, 106, 112, 133, 136, 136, 201, 210, 225, 232, 238,
#            239, 251, 257, 263, 549, 581, 588, 602, 645]),
#     array([426]),
#     array([  2, 547]),
#     array([  1, 892, 945, 997]),
#     array([590, 643, 780]),
#     array([642, 654]),
#     array([ 52, 456, 679]),
#     array([468, 505, 558, 735]),
#     array([382, 461, 601, 647, 664]),
#     array([135, 223, 293, 483, 780, 815, 818, 831, 848, 857, 861, 877, 880,
#            883, 883, 893, 930, 932, 934, 935, 939, 951, 957, 963, 964, 966,
#            982, 988, 997]),
#     array([], dtype=int64),
#     array([ 16,  55,  82, 110, 128, 260, 268, 269, 273, 437, 438, 464, 489,
#            574, 714, 715, 726, 768, 936]),
#     array([ 58, 442, 530, 790, 810, 837, 977]),
#     array([ 18,  51,  78,  84,  85,  89, 109, 331]),
#     array([479, 541, 580, 581, 587, 665, 676, 684, 700, 711, 718, 902]),
#     array([ 86,  86,  99, 106, 146, 290, 375, 383, 404, 404, 505, 552, 555]),
#     array([ 83, 173, 337, 366, 387, 389, 403, 412, 483, 528, 543, 602, 604]),
#     array([ 26, 234, 902]),
#     array([ 17,  49,  58,  66,  84,  86,  93, 119, 122, 127, 130, 130, 132,
#            134, 152, 157, 177, 180, 190, 193, 206, 227, 256, 259, 263, 276,
#            277, 332, 337, 342, 343, 407, 437, 449, 457, 473, 474, 514, 519,
#            519, 589, 600, 605, 770, 771, 792, 837, 846, 852, 876, 942, 966]),
#     array([447]),
#     array([502, 509, 548]),
#     array([289, 333, 518, 570, 575, 578, 613, 626, 710, 783, 887, 960]),
#     array([730, 766])]},
#   24: {0: [array([  8, 152, 535, 691, 733, 797, 850]),
#     array([140, 530, 583, 608, 609, 792, 810]),
#     array([  0, 200, 239, 446, 549, 555, 611, 724, 822, 875, 993]),
#     array([ 66,  73, 297, 394, 406, 430, 506, 667, 863, 946, 974]),
#     array([ 43, 172, 240, 301, 620, 690, 947, 951, 965]),
#     array([ 75, 113, 187, 219, 269, 365, 439, 443, 463, 565, 673]),
#     array([ 63, 196, 283, 545, 675, 688, 718, 731]),
#     array([ 84, 379, 525, 706, 727, 989]),
#     array([  2,  53, 147, 170, 197, 280, 383, 443, 516, 530, 727, 753, 919]),
#     array([ 26, 201, 220, 278, 332, 431, 696, 824, 865]),
#     array([207, 278, 403, 536, 675, 793]),
#     array([ 70, 128, 191, 441, 456, 633, 698, 756, 764, 858, 898, 999]),
#     array([ 74, 284, 726, 833]),
#     array([247, 281, 360, 543, 555, 560, 568, 602, 908, 939, 944, 958]),
#     array([241, 250]),
#     array([  5, 115, 391, 506, 618, 684]),
#     array([437, 701, 869, 956]),
#     array([601, 633]),
#     array([137, 556, 677, 727, 764, 939, 971]),
#     array([205, 687, 734, 750, 903]),
#     array([234, 277, 314, 493, 622, 811, 819, 831, 963, 982]),
#     array([466, 673, 828]),
#     array([ 16,  37, 329, 714, 936, 992]),
#     array([ 42,  58, 342, 605, 711, 718, 774]),
#     array([ 42, 295, 563, 681, 905]),
#     array([ 50,  52, 131, 195, 278, 419, 462, 507, 743, 884, 979]),
#     array([ 46,  85, 292, 868, 904, 970]),
#     array([ 27,  36, 144, 206, 354, 459, 514, 546, 631, 706, 724, 728, 787,
#            792, 887, 892, 957, 993]),
#     array([279, 284, 965]),
#     array([ 89, 121, 529, 613, 626, 700, 776, 946]),
#     array([ 95, 508, 563, 656, 887]),
#     array([337, 380, 760, 812]),
#     array([111, 169, 338, 397, 487, 670]),
#     array([ 30, 242, 410, 457, 657, 689, 692, 762, 817, 919, 954, 980]),
#     array([ 12,  48,  59, 447, 681, 766]),
#     array([136, 294, 413, 601, 711]),
#     array([109, 353, 403, 986]),
#     array([ 22,  24, 132, 146, 255, 266, 315, 798, 814, 833, 972]),
# ...
#            938]),
#     array([147, 167, 169, 226, 268, 305, 318, 324, 358]),
#     array([ 26, 384, 434]),
#     array([241, 477, 720]),
#     array([], dtype=int64),
#     array([134, 147, 164, 196, 234, 278, 303, 407, 699, 739, 808, 936]),
#     array([  1,  87, 640, 978]),
#     array([ 59,  75,  95,  97, 104, 105, 110, 215, 294, 390, 401, 552, 759,
#            950, 969, 996]),
#     array([281, 531, 713, 886]),
#     array([363, 442, 584, 668, 669, 691, 926]),
#     array([186, 468, 945]),
#     array([ 43,  97,  99,  99, 131, 196, 208, 248, 256, 262, 284, 297, 300,
#            308, 366, 582, 621]),
#     array([ 34,  42,  88,  95, 123, 131, 136, 183, 196, 201, 285, 492, 555,
#            580, 628, 996]),
#     array([112, 179, 312, 646, 834]),
#     array([ 63, 446, 482, 499, 993]),
#     array([ 81, 266, 316, 425, 463, 476, 508, 548, 581, 589, 625, 641, 708,
#            717, 730, 731, 754, 772, 778, 799, 934, 936, 941]),
#     array([301, 589, 725, 808, 860, 876, 944, 957]),
#     array([123, 495, 692, 693, 705, 893, 899]),
#     array([170, 176, 350, 401, 491, 828, 955]),
#     array([837, 866, 899, 935]),
#     array([553, 843, 846, 947]),
#     array([ 66, 114, 554, 832, 972])]},
#   992: {0: [array([ 66,  69, 154, 376, 765, 826, 841, 844, 869, 872, 876, 955, 955,
#            966, 994, 994, 996]),
#     array([113, 129, 143, 154, 154, 157, 201, 219, 222, 233, 294, 341, 375,
#            377, 383, 404, 804, 805, 815, 815, 821, 821, 824, 851]),
#     array([], dtype=int64),
#     array([750, 820, 868, 906, 910, 922, 926, 935, 935, 953, 953, 964, 972,
#            980, 986, 988, 995, 996, 997]),
#     array([ 44,  84,  95, 116, 147, 149, 176, 534]),
#     array([452, 504, 555, 586, 592, 641, 655, 672, 701, 710, 729, 731, 741,
#            775]),
#     array([616, 941]),
#     array([ 42, 102, 115, 148]),
#     array([722]),
#     array([138, 203, 259, 285, 288, 289, 325, 345, 355, 405, 411, 471, 575,
#            585, 605, 612, 692, 736, 809, 939]),
#     array([330, 330, 347, 348]),
#     array([  1,  11,  14,  20,  27,  38,  61, 631]),
#     array([  2,   6,  11,  24,  26,  30,  30,  43,  47,  85,  90, 138, 163,
#            174]),
#     array([110, 870, 878]),
#     array([114, 152, 212, 545, 552, 563, 585, 649, 654, 663, 669, 943, 974]),
#     array([ 91, 353, 353, 361, 372, 372, 377, 378, 385, 399, 477, 595, 601,
#            655, 720, 725, 756, 758, 816, 820, 828]),
#     array([550]),
#     array([683, 688]),
#     array([186, 223, 236, 269, 270, 315, 454, 647, 670, 671, 709, 711, 712,
#            735, 743]),
#     array([], dtype=int64),
#     array([298, 322, 353, 358]),
#     array([199]),
#     array([310]),
#     array([110, 111, 950]),
#     array([], dtype=int64),
#     array([456, 459, 484, 529, 554, 606]),
#     array([132, 152, 163, 164, 169, 174, 183, 208, 236, 280, 316, 352, 357,
#            363, 379, 390, 391, 405, 409, 434, 440, 445, 490, 503, 525]),
#     array([711]),
#     array([], dtype=int64),
#     array([160]),
#     array([647, 650, 659, 668, 669, 681, 684, 685, 699, 726, 758, 787, 797,
#            840]),
#     array([31]),
#     array([324]),
#     array([365, 367, 367, 418, 419]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([796, 811, 832, 938, 950, 986, 986, 988]),
#     array([189, 207, 214, 247, 291, 322, 327, 882]),
#     array([ 62,  94, 100, 379]),
#     array([  5,   9,  16,  61, 404, 407, 424, 826, 833, 839, 843, 845, 853,
#            853, 900])]},
#   993: {0: [array([], dtype=int64),
#     array([805, 813, 814]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([547, 591, 600]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([978]),
#     array([706, 721, 736, 754]),
#     array([], dtype=int64),
#     array([750, 755, 758, 806, 820, 838]),
#     array([], dtype=int64),
#     array([808, 818, 826]),
#     array([435, 452]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([147]),
#     array([], dtype=int64),
#     array([447]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([70]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([165, 169]),
#     array([ 18, 306, 317]),
#     array([294, 298, 308, 321, 387, 420, 861, 879, 907]),
#     array([791, 829, 848, 849, 855, 858, 858, 863, 864, 865, 865, 868, 869,
#            870, 878, 878, 885, 888, 890, 903, 906, 913, 913, 948, 953, 994,
#            994]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([  5,  19,  19,  21,  31,  35,  36,  38,  47,  47,  48,  48,  49,
#             57,  61,  62,  68,  72,  85,  85,  89,  96, 104, 119, 128, 175,
#            196, 499]),
#     array([400, 404]),
#     array([], dtype=int64),
#     array([115, 130, 140, 194]),
#     array([], dtype=int64),
#     array([355, 360, 366, 379, 385, 389, 407, 593]),
#     array([], dtype=int64)]},
#   994: {0: [array([], dtype=int64),
#     array([ 73, 115, 732, 954]),
#     array([725]),
#     array([163, 265, 282, 344, 396, 429, 521]),
#     array([257, 279]),
#     array([ 23, 366, 647]),
#     array([421, 444, 497, 798, 920]),
#     array([160, 385, 427, 658, 737, 771, 788]),
#     array([120, 571, 580, 959, 996]),
#     array([277]),
#     array([133, 221, 240, 269, 320, 321, 324, 536, 568, 983]),
#     array([ 51,  57,  77,  94, 121, 155, 463, 532, 779]),
#     array([  6,   9, 125, 188, 207, 282, 308, 309, 314, 357, 384, 398, 406,
#            417, 495, 506, 513, 514, 569, 573, 581, 588, 597, 744]),
#     array([232, 311, 833, 888, 924, 930]),
#     array([549, 582, 657, 818]),
#     array([308, 430, 479, 502, 522, 524, 538, 572, 576, 582, 639]),
#     array([ 38, 318, 319, 343, 357, 430, 486, 521, 527, 542, 551, 619, 632,
#            665, 671, 714, 774, 819, 881, 963, 992]),
#     array([350, 429]),
#     array([573, 600, 952]),
#     array([426, 876, 951, 969, 975, 985]),
#     array([ 72, 173, 415, 823, 843]),
#     array([ 22,  32,  79,  89, 103, 103, 116, 127, 134, 185, 218, 234, 235,
#            281, 293, 325, 342, 516, 570, 619, 625, 689, 769]),
#     array([148, 428, 429, 453, 467, 540, 596, 631, 637, 652, 661, 729, 742,
#            775, 781, 824, 884, 929, 991]),
#     array([189]),
#     array([624, 653, 723]),
#     array([ 15,  48, 201, 226, 230, 260, 337, 342, 374, 740]),
#     array([224, 236, 300, 333, 468, 541, 767, 784, 931]),
#     array([414, 594, 649, 665, 873, 935, 936]),
#     array([ 95, 104, 125, 144, 586, 595, 608, 621, 633, 868, 871, 877, 887,
#            936, 962, 993, 996]),
#     array([314, 477]),
#     array([101, 104, 112, 214, 740, 782, 817]),
#     array([ 13,  78, 614, 771]),
#     array([128, 137, 158, 177, 619, 628, 641, 654, 666, 901, 904, 910, 920,
#            969, 995]),
#     array([ 78, 278, 627, 671, 675, 725, 912]),
#     array([ 10,  41,  47,  56,  81, 182, 909, 953, 956, 963]),
#     array([163, 210, 271, 321, 331, 339, 550, 553, 584, 616, 619, 665, 666,
#            721, 772, 775, 783, 834, 836, 844, 850, 883, 887, 907, 910, 911,
#            921, 935, 936, 940, 958]),
#     array([ 24, 522, 596, 599, 605, 721, 811, 826, 841, 925, 946]),
#     array([ 80,  88, 324, 912]),
#     array([367, 446, 547, 802]),
#     array([652, 869, 927, 937, 952, 965, 993])]},
#   995: {0: [array([124, 141, 233, 284, 285, 418, 453, 554, 669, 821, 836]),
#     array([250, 432, 502, 558, 645, 716]),
#     array([336, 373, 414, 612, 632, 797]),
#     array([251, 394, 983]),
#     array([926]),
#     array([186, 697]),
#     array([513, 827]),
#     array([187, 795]),
#     array([270, 389, 487, 633, 664]),
#     array([ 26, 121, 176, 441, 519, 541, 590, 734]),
#     array([ 19,  45, 320, 368, 398, 452, 564]),
#     array([206, 356, 418, 472]),
#     array([347]),
#     array([298, 535, 663, 801, 848]),
#     array([117, 862, 883]),
#     array([ 22,  94, 447, 513, 666, 724]),
#     array([127, 155, 224, 911]),
#     array([114, 561, 719]),
#     array([], dtype=int64),
#     array([981]),
#     array([563, 617]),
#     array([  5,  23, 148, 306, 748, 849, 850, 887, 926, 963]),
#     array([363, 422, 631, 921]),
#     array([130, 135, 248, 607, 658]),
#     array([193, 194, 286, 306, 336, 365, 503, 773, 777]),
#     array([144, 291, 322, 359, 579, 583, 586, 698, 726]),
#     array([], dtype=int64),
#     array([ 10, 144, 425, 501]),
#     array([150]),
#     array([ 92, 170, 689, 698, 848, 912]),
#     array([301, 412, 521, 626, 750, 804, 929, 969]),
#     array([413, 720, 802, 863, 975]),
#     array([893]),
#     array([ 79, 117, 562, 614, 614, 913]),
#     array([450, 528, 738, 776]),
#     array([ 99, 139, 218, 238, 262, 264, 323, 671, 698, 759, 975]),
#     array([ 89, 270, 371, 421, 437, 452, 694, 760]),
#     array([107, 117, 365]),
#     array([  7, 121, 514, 550, 735, 900]),
#     array([], dtype=int64)]},
#   996: {0: [array([183, 197, 207, 216, 218, 470, 548]),
#     array([ 19,  19,  74, 107, 186, 188, 192, 195, 210, 244, 274, 292, 325,
#            684, 688, 713, 738, 886]),
#     array([496, 856, 889, 981]),
#     array([], dtype=int64),
#     array([  7,   7,  14,  26,  27,  47,  60,  61, 490, 503, 542, 567, 582,
#            718]),
#     array([ 20, 782, 957]),
#     array([ 38,  51,  67,  80,  93, 104, 114, 170, 192, 219, 233, 236, 552,
#            566, 619, 682, 686, 717, 722, 732]),
#     array([122, 224, 699, 790, 982]),
#     array([ 22,  25, 167, 187, 967]),
#     array([695]),
#     array([], dtype=int64),
#     array([630, 676, 700, 864, 918, 919, 981]),
#     array([575, 759, 803, 803]),
#     array([246, 258, 270]),
#     array([707, 713, 721, 729, 736, 764, 809, 847, 849, 857, 936]),
#     array([738, 868, 916, 922, 959]),
#     array([162, 201]),
#     array([852]),
#     array([455, 458, 489, 504, 634, 661, 866]),
#     array([256, 475]),
#     array([400, 905, 912, 941, 941, 948, 963, 973, 985]),
#     array([474, 504, 547, 691, 720, 739, 765, 874, 884, 895, 900, 953]),
#     array([302, 509, 529, 532, 851]),
#     array([ 59, 243, 287, 287, 592, 787, 838, 871, 880, 887, 890, 977, 978,
#            989]),
#     array([ 19,  54,  68, 101, 117, 228, 292, 294, 325, 338, 349, 417, 764,
#            777, 778, 787, 809, 841]),
#     array([], dtype=int64),
#     array([196]),
#     array([164, 468, 496, 571, 727, 740, 764]),
#     array([183, 253, 414, 525, 558, 593, 606, 615, 618, 622, 623, 649, 660,
#            661, 673, 674, 677, 679, 687, 707, 715, 721, 729, 734, 740, 770,
#            803, 824, 834, 853, 860, 892]),
#     array([ 86, 128, 423, 465, 478]),
#     array([], dtype=int64),
#     array([807, 898]),
#     array([], dtype=int64),
#     array([484, 748, 748, 774]),
#     array([119, 739, 814, 822, 829]),
#     array([241, 289, 357, 362]),
#     array([], dtype=int64),
#     array([ 24,  27,  45,  53,  64, 110, 151, 155, 181, 231, 457, 473, 489]),
#     array([ 11,  20,  42, 272]),
#     array([412, 414, 424, 429, 444, 478, 479, 639, 640, 654, 749, 992])]},
#   997: {0: [array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64)]},
#   998: {0: [array([ 45, 107, 184, 536, 616, 623, 633, 646, 650, 670, 765, 767, 769,
#            782, 938, 953, 963]),
#     array([233, 279, 593, 700, 719, 719, 724, 784, 809, 870, 899]),
#     array([ 94, 103, 249, 251, 750, 884]),
#     array([ 66,  73, 144, 350, 359, 449, 480, 520, 629, 635, 758]),
#     array([ 22, 106, 137, 215, 303, 470, 479, 532, 550, 857, 929]),
#     array([124, 183, 385, 607, 626, 808, 856, 950]),
#     array([522, 771, 830, 851, 882]),
#     array([ 26, 238, 386, 404, 546, 548, 636, 678, 694, 878, 976]),
#     array([194, 199, 463, 561, 631, 644, 648, 752, 826, 881, 911]),
#     array([ 52, 199, 239, 317, 358, 549, 732, 739, 900, 949]),
#     array([ 17, 103, 136, 141, 177, 191, 223, 308, 335, 341, 437, 498, 566,
#            627, 671, 688, 882, 886, 986]),
#     array([154, 155, 171, 188, 206, 340, 494, 778]),
#     array([179, 439, 608, 692, 719]),
#     array([528, 533, 629, 721, 741, 861]),
#     array([ 26, 220, 354, 661, 936, 938, 997]),
#     array([ 75,  94, 123, 444, 500, 756, 848, 898, 922, 969]),
#     array([ 52,  91, 123, 130, 142, 190, 229, 277, 400, 625, 658, 741, 875,
#            882]),
#     array([ 20,  70, 109, 236, 242, 265, 268, 282, 340, 355, 389, 432, 439,
#            450, 588, 658, 679, 772, 919, 959]),
#     array([167, 443, 475, 500, 550, 597, 664, 667, 667, 874, 880, 926, 943,
#            950, 988]),
#     array([137, 155, 170, 181, 264, 330, 342, 381, 433, 739]),
#     array([449, 469, 596, 894]),
#     array([ 49, 371, 466, 582, 602, 887, 893, 978]),
#     array([ 80, 721, 727, 822, 941, 943]),
#     array([109, 136, 205, 216, 354, 412, 426, 506, 554, 568, 607, 641]),
#     array([105, 168, 446, 475, 504, 522, 647, 673, 915]),
#     array([ 14, 380, 388, 397, 460, 475, 567, 579, 626, 632]),
#     array([  6, 305, 516, 590, 622, 728, 802, 949]),
#     array([ 44, 616, 980]),
#     array([  9, 393, 452, 654, 876, 895]),
#     array([276, 309, 414, 504, 518, 739, 741, 837]),
#     array([225, 445, 469, 525, 575, 614, 741, 747, 770, 773, 787, 845, 860,
#            894, 937, 944, 955]),
#     array([  4, 129, 299, 348, 453, 456, 541, 583, 652, 707]),
#     array([ 45, 117, 398, 459, 494, 621, 700, 743]),
#     array([ 67,  89, 270, 437, 652, 661, 661, 702, 722, 805, 850, 853, 929,
#            964]),
#     array([ 39, 418, 999]),
#     array([207, 257, 334, 406, 462, 517, 536, 544, 980]),
#     array([117, 215, 228, 261, 359, 394, 504, 905, 935]),
#     array([ 97, 106, 230, 386, 426, 546, 796, 864, 984]),
#     array([ 63, 468, 502, 514, 757, 819]),
#     array([118, 425, 749, 889, 947, 978])]},
#   999: {0: [array([680, 741, 751, 921]),
#     array([529, 788, 900, 930]),
#     array([102, 347, 764]),
#     array([], dtype=int64),
#     array([173, 632, 726]),
#     array([194, 217, 802, 913]),
#     array([195, 671, 673, 775, 832, 944]),
#     array([ 70, 221, 293, 452, 538]),
#     array([ 42, 567, 597, 640, 765, 775, 777]),
#     array([216, 600, 670, 907, 969]),
#     array([671, 693]),
#     array([], dtype=int64),
#     array([328, 381]),
#     array([461]),
#     array([533, 953]),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([], dtype=int64),
#     array([794]),
#     array([966, 978]),
#     array([], dtype=int64),
#     array([145, 355, 417, 523]),
#     array([319, 591]),
#     array([338]),
#     array([369, 971]),
#     array([504]),
#     array([  7, 194, 250, 410, 571, 638, 641, 785, 838, 943]),
#     array([278, 349, 357]),
#     array([219, 345, 419, 480, 550, 558, 619, 942, 996]),
#     array([667, 731, 739, 786, 824, 841, 863, 924]),
#     array([453]),
#     array([701, 757, 785, 849, 927]),
#     array([ 24, 438]),
#     array([372, 884, 978]),
#     array([592, 887]),
#     array([], dtype=int64),
#     array([267, 689]),
#     array([169, 435, 819, 889]),
#     array([600, 845, 888]),
#     array([ 57, 277, 323, 448, 476, 477, 485, 499, 520, 525, 560, 592, 784,
#            814])]},
#   ...},
#  'n_trials': array([40, 40, 40, ..., 40, 40, 40]),
#  'trial_lens': array([1000, 1000, 1000, ..., 1000, 1000, 1000]),
#  'alphas': array([0.85109859, 0.85809782, 0.52880549, ..., 0.25891475, 0.1876196 ,
#         0.13418378]),
#  'fr_values': array([7.74182093, 4.39439561, 8.58739322, ..., 5.60444112, 1.21905713,
#         9.30888525]),
#  'tau_ms': array([150.9235152 , 147.94723277, 267.00228951, ..., 174.18967241,
#          76.56579681, 175.30929016])}

# %%
idx = 10

spike_trains = data['trial_dict'][idx][0]

# %%
duration_ms = 1000
num_trials = len(spike_trains)

# Initialize output (num_trials x duration_ms)
binary_trains = np.zeros((num_trials, duration_ms), dtype=np.uint8)

for i, spikes in enumerate(spike_trains):
    # Keep only spikes within 0–999 ms
    valid_spikes = spikes[(spikes >= 0) & (spikes < duration_ms)]
    # Mark spikes as 1 (use unique to avoid duplicates)
    binary_trains[i, np.unique(valid_spikes)] = 1

print(binary_trains.shape)        # (n_trials, 1000)
print(np.sum(binary_trains, 1))   # number of spikes per trial

print(f'FR {fr_values[idx]}, true TAU {taus_ms[idx]}, alpha {alphas[idx]}')
# Out:
# (40, 1000)
# [ 3  2  0  2  9  5  6  3  3  2  0  3  7  0  3  9 10  1  2 11  2  1  1  1
#   0  3  1  4  0 13  2  7  8  5  2  1  0  2  2  1]
# FR 3.7142722620834863, true TAU 214.20915975815137, alpha 0.4510552484424556

# %% [markdown]
# ### Step 1: Extracting required statistics from real data
#
# First load your data and use "extract_stats" functions to compute statistics.

# %%
#---------- extract statistics from real data
# select summary statistics metric
summStat_metric = 'comp_cc'
ifNorm = True # if normalize the autocorrelation or PSD
deltaT = 1 # temporal resolution of data.
binSize = 50 #  bin-size for binning data and computing the autocorrelation.
disp = None # put the dispersion parameter if computed with grid-search
maxTimeLag = 1000 # only used when using autocorrelation for summary statistics
lm = round(maxTimeLag/binSize) # maximum bin for autocorrelation computation
data_sumStat, data_mean, data_var, T, numTrials = abcTau.preprocessing.extract_stats(binary_trains, deltaT, binSize,\
                                                                                  summStat_metric, ifNorm, maxTimeLag)

print(data_sumStat.shape)

plt.plot(data_sumStat)
# Out:
# (20,)

# %%
print(data_mean, data_var, T, numTrials)
# Out:
# 0.17125 0.19668750000000002 1000 40

# %% [markdown]
# ### Step 3: Estimation of timescales using the aABC algorithm
#
# Fitting one timescale in time domain
#
# The duration for fitting the generative model with the aABC algorithm depends on the size of your data, selected summary statistics (e.g., fastest is with the PSD), number of accepted samples in posteriors (min_samples), final selected accepatance rate (minAccRate), and computational resources (e.g., number of cores in parallel processing). Depending on these parameters the fitting duration is in between ~5-20 min (usually for fitting PSD as summary statistic and parallel processing, see Supplementary Table 1 in the paper for more details) up to ~4-8 hours (wihtout any parallel processing).

# %%
# 4. Select the desired generative model from the list of 'generative_models.py' and the distance function from 'diatance_functions.py'
# select generative model and distance function
generativeModel = 'oneTauOU'
distFunc = 'linear_distance'

# 5. Define the prior distributions
# Define a uniform prior distribution over the given range
# for a uniform prior: stats.uniform(loc=x_min,scale=x_max-x_min)
t_min = 0.0 # first timescale
t_max = 400.0
priorDist = [stats.uniform(loc= t_min, scale = t_max - t_min)]

# 6. Set the aABC fitting parameters
# set fitting params
epsilon_0 = 1  # initial error threshold
min_samples = 100 # min samples from the posterior
steps = 60 # max number of iterations
minAccRate = 0.01 # minimum acceptance rate to stop the iterations
parallel = False # if parallel processing
n_procs = 1 # number of processor for parallel processing (set to 1 if there is no parallel processing)

# %%
# 7. Create the model object: Just copy paste the following (this a general definition of the model object, but all parts 
# including generative models, summary statistics computation or distance function can be replaced by your own functions. 
# You can add your handmade functions inside respected modules: "generative_models.py", "distance_functions.py", "summary_stats.py")

# creating model object
class MyModel(abcTau.Model):

    #This method initializes the model object.  
    def __init__(self):
        pass

    # draw samples from the prior. 
    def draw_theta(self):
        theta = []
        for p in self.prior:
            theta.append(p.rvs())
        return theta

    # Choose the generative model (from generative_models)
    # Choose autocorrelation computation method (from basic_functions)
    def generate_data(self, theta):
        # generate synthetic data
        if disp == None:
            syn_data, numBinData =  eval('abcTau.generative_models.' + generativeModel + \
                                         '(theta, deltaT, binSize, T, numTrials, data_mean, data_var)')
        else:
            syn_data, numBinData =  eval('abcTau.generative_models.' + generativeModel + \
                                         '(theta, deltaT, binSize, T, numTrials, data_mean, data_var, disp)')
               
        # compute the summary statistics
        syn_sumStat = abcTau.summary_stats.comp_sumStat(syn_data, summStat_metric, ifNorm, deltaT, binSize, T,\
                                          numBinData, maxTimeLag)   
        return syn_sumStat

    # Computes the summary statistics
    def summary_stats(self, data):
        sum_stat = data
        return sum_stat

    # Choose the method for computing distance (from basic_functions)
    def distance_function(self, data, synth_data):
        if np.nansum(synth_data) <= 0: # in case of all nans return large d to reject the sample
            d = 10**4
        else:
            d = eval('abcTau.distance_functions.' +distFunc + '(data, synth_data)')        
        return d

# %%
# 8. Run the aABC algorithm and save the results
# fit with aABC algorithm for any generative model
abc_results, final_step = abcTau.fit.fit_withABC(MyModel, data_sumStat, priorDist, inter_save_direc, inter_filename,\
                                                 datasave_path,filenameSave, epsilon_0, min_samples, \
                                                 steps, minAccRate, parallel, n_procs, disp)
# Out:
# Starting step 0
# epsilon = 1
# acceptence Rate = 0.970873786407767
# --------------------
# Starting step 1
# epsilon = 0.035609997509564506
# acceptence Rate = 0.6622516556291391
# --------------------
# Starting step 2
# epsilon = 0.03027491183726278
# acceptence Rate = 0.5952380952380952
# --------------------
# Starting step 3
# epsilon = 0.02370840300165005
# acceptence Rate = 0.6097560975609756
# --------------------
# Starting step 4
# epsilon = 0.018103108342988613
# acceptence Rate = 0.6622516556291391
# --------------------
# Starting step 5
# epsilon = 0.01449439734077089
# acceptence Rate = 0.5405405405405406
# --------------------
# Starting step 6
# epsilon = 0.012831919176293886
# acceptence Rate = 0.6134969325153374
# --------------------
# Starting step 7
# epsilon = 0.011568603619703847
# acceptence Rate = 0.5747126436781609
# --------------------
# Starting step 8
# epsilon = 0.010653093216140608
# acceptence Rate = 0.4166666666666667
# --------------------
# Starting step 9
# epsilon = 0.009795779048768145
# acceptence Rate = 0.3597122302158273
# --------------------
# Starting step 10
# epsilon = 0.009315599268093304
# acceptence Rate = 0.33222591362126247
# --------------------
# Starting step 11
# epsilon = 0.00876237266982221
# acceptence Rate = 0.18726591760299627
# --------------------
# Starting step 12
# epsilon = 0.008351273831657964
# acceptence Rate = 0.2074688796680498
# --------------------
# Starting step 13
# epsilon = 0.007904414280894001
# acceptence Rate = 0.14792899408284024
# --------------------
# Starting step 14
# epsilon = 0.007581449365791606
# acceptence Rate = 0.10309278350515463
# --------------------
# Starting step 15
# epsilon = 0.007155041637895713
# acceptence Rate = 0.09560229445506692
# --------------------
# Starting step 16
# epsilon = 0.006821106720436851
# acceptence Rate = 0.07072135785007072
# --------------------
# Starting step 17
# epsilon = 0.006496902276283498
# acceptence Rate = 0.049019607843137254
# --------------------
# Starting step 18
# epsilon = 0.006312771601463956

# %% [markdown]
# ### Plotting the results
#
# (took examples from other tutorials - I downloaded them before)

# %%
# load abc results
filename = 'test_steps22'
abc_results = np.load(datasave_path + filename + '.npy', allow_pickle=True)
ind = filename.find('steps') 
final_step = int(filename[ind+5] + filename[ind+6])

# extract estimated parameters
theta_accepted = abc_results[final_step-1]['theta accepted']
tau1 = theta_accepted[0]

# extract the development of the error threshold and acceptance rate during fitting (discarding first iteration)
eps = []
accR = []
steps = np.arange(1,final_step+1)[1:]
for i in range(final_step): 
    step_results = abc_results[i]
    eps.append(step_results['epsilon'])
    accR.append(step_results['n accepted']/step_results['n total'])
eps = eps[1:]
accR = accR[1:]

# ground truth values 
tau1_gt = 150

# %%
np.mean(tau1)

# %%
# plot the results
fig = plt.figure(figsize = (24,6))

# plotting variables
cABC = 'darkorange'
ctheor = 'gray'
cAccR = 'r'
cErr = 'b'
a = 0.5
lw = 3

ax = plt.subplot(141)
ax.hist(tau1, facecolor= cABC, density=True, alpha = a, label = r'Estimated')
sns.kdeplot(tau1, color = cABC)
plt.axvline(tau1_gt, color = ctheor, label = r'Ground truth', linewidth = lw, linestyle = '--')

ax.set_xlabel(r'$\tau_1$ [ms]')
ax.set_ylabel('Probability density')
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.legend(frameon = False, bbox_to_anchor=(0.4, 1))

fig.tight_layout()

# %%
sttc_results_folder = 'E:\\work\\q_backup_06_03_2025\\projects\\isttc\\results\\synthetic\\results\\param_fr_alpha_tau\\'

df_all = pd.read_pickle(sttc_results_folder + "summary_tau_all_long_df.pkl")

# %%
df_all[df_all['unit_id'] == 0]
