# %%
import numpy as np
import pandas as pd
import pickle

from isttc.scripts.cfg_global import project_folder_path

# %%
dataset_folder = project_folder_path + 'synthetic_dataset\\'
results_folder = project_folder_path + 'results\\synthetic\\results\\param_fr_alpha_tau_comp_time\\full_signal\\'

# %%
with open(results_folder + 'z_tau_acf_full_50ms_20lags_dict.pkl', "rb") as f:
    acf_full_dict = pickle.load(f)

# %%
acf_full_dict
# Out:
# {0: {'taus': {'tau': np.float64(2.2178994948528157),
#    'tau_lower': np.float64(2.119224323557929),
#    'tau_upper': np.float64(2.3165746661477025),
#    'fit_r_squared': 0.9983688249951346,
#    'explained_var': 0.9983688249951346,
#    'popt': array([1.07744127e+00, 2.21789949e+00, 9.23617009e-04]),
#    'pcov': array([[ 3.10683507e-04, -6.62747657e-04,  6.97780985e-06],
#           [-6.62747657e-04,  2.20595121e-03, -5.37909130e-05],
#           [ 6.97780985e-06, -5.37909130e-05,  4.60988538e-06]]),
#    'log_message': 'ok'},
#   'acf': array([ 1.00000000e+00,  6.85447506e-01,  4.40920991e-01,  2.86195558e-01,
#           1.72939296e-01,  1.12080550e-01,  6.62808050e-02,  4.00935381e-02,
#           2.67535828e-02,  2.73342589e-02,  2.60284943e-02,  2.41372826e-02,
#           1.09198159e-02,  7.66256087e-03,  8.27576179e-03, -6.73340124e-04,
#          -2.75970089e-03, -8.84661692e-03, -8.36351537e-03, -4.92065341e-03,
#           1.44944410e-03]),
#   'elapsed_time_acf': 0.0010742000304162502,
#   'elapsed_time_tau_fit': 0.24353430001065135},
#  1: {'taus': {'tau': np.float64(2.5682102430291525),
#    'tau_lower': np.float64(2.437150283223527),
#    'tau_upper': np.float64(2.699270202834778),
#    'fit_r_squared': 0.9978989453343503,
#    'explained_var': 0.9978989453343503,
#    'popt': array([ 1.04891045,  2.56821024, -0.01869286]),
#    'pcov': array([[ 3.32387868e-04, -8.73627239e-04,  1.56552176e-05],
#           [-8.73627239e-04,  3.89152824e-03, -1.19670576e-04],
#           [ 1.56552176e-05, -1.19670576e-04,  8.49072782e-06]]),
#    'log_message': 'ok'},
#   'acf': array([ 1.        ,  0.67781125,  0.4779327 ,  0.32353495,  0.19293637,
#           0.13115741,  0.07678981,  0.03600199,  0.01749424,  0.00225485,
#          -0.00133814, -0.00401047, -0.01188455, -0.01736491, -0.01663078,
#          -0.01078697, -0.01530062, -0.01479666, -0.01226724, -0.00821872,
#          -0.01305461]),
#   'elapsed_time_acf': 0.0010742000304162502,
#   'elapsed_time_tau_fit': 0.004024899913929403},
#  2: {'taus': {'tau': np.float64(5.2274513597843075),
#    'tau_lower': np.float64(4.334421061468414),
#    'tau_upper': np.float64(6.120481658100201),
#    'fit_r_squared': 0.9849601314477014,
#    'explained_var': 0.9849601314477014,
#    'popt': array([0.25716482, 5.22745136, 0.02099525]),
#    'pcov': array([[ 7.40649936e-05, -1.62768583e-03,  3.45332330e-07],
#           [-1.62768583e-03,  1.80681011e-01, -6.52529574e-03],
#           [ 3.45332330e-07, -6.52529574e-03,  3.41117930e-04]]),
#    'log_message': 'ok'},
#   'acf': array([ 1.        ,  0.2149054 ,  0.18696226,  0.15161464,  0.12184618,
#           0.09537125,  0.09503029,  0.06392059,  0.07064687,  0.05577073,
#           0.03944625,  0.03845454,  0.02450292,  0.02762217,  0.02390436,
#           0.02297613,  0.02653584,  0.00454885,  0.01815582, -0.0037677 ,
#           0.0227793 ]),
#   'elapsed_time_acf': 0.0010742000304162502,
#   'elapsed_time_tau_fit': 0.005145599949173629},
#  3: {'taus': {'tau': np.float64(3.950209328510561),
#    'tau_lower': np.float64(2.2500841515048555),
#    'tau_upper': np.float64(5.650334505516266),
#    'fit_r_squared': 0.8897187811014433,
#    'explained_var': 0.8897187811014433,
#    'popt': array([ 0.12234563,  3.95020933, -0.02731036]),
#    'pcov': array([[ 1.81132929e-04, -6.86627675e-03,  1.14759163e-04],
#           [-6.86627675e-03,  6.54850138e-01, -2.32941277e-02],
#           [ 1.14759163e-04, -2.32941277e-02,  1.31842416e-03]]),
#    'log_message': 'ok'},
#   'acf': array([ 1.00000000e+00,  9.75923207e-02,  6.41391826e-02,  4.83456063e-02,
#           3.36772840e-02,  3.75094550e-02,  4.63872151e-02,  5.65001579e-03,
#           9.19786432e-03,  1.40811997e-02,  3.90185739e-03,  3.66551411e-03,
#          -2.03688401e-03,  8.31250621e-03,  2.52598103e-05, -1.41485072e-02,
#           9.86602014e-03, -1.78987944e-02,  1.04565338e-02, -4.27596709e-04,
#          -3.11264496e-03]),
#   'elapsed_time_acf': 0.0010742000304162502,
#   'elapsed_time_tau_fit': 0.007440799963660538},
#  4: {'taus': {'tau': np.float64(3.7179634791306477),
#    'tau_lower': np.float64(3.426456297057045),
#    'tau_upper': np.float64(4.00947066120425),
#    'fit_r_squared': 0.9957371559462932,
#    'explained_var': 0.9957371559462932,
#    'popt': array([0.57239585, 3.71796348, 0.08026378]),
#    'pcov': array([[ 1.45005741e-04, -1.09690671e-03, -8.10928852e-06],
#           [-1.09690671e-03,  1.92521237e-02, -4.68740038e-04],
#           [-8.10928852e-06, -4.68740038e-04,  3.72273281e-05]]),
#    'log_message': 'ok'},
#   'acf': array([1.        , 0.49114451, 0.36256096, 0.30875511, 0.24309426,
#          0.19749572, 0.16192833, 0.12271325, 0.11997509, 0.09261501,
#          0.088053  , 0.09078639, 0.06069054, 0.04974507, 0.05977384,
#          0.05977145, 0.05885714, 0.05338321, 0.05155698, 0.05246652,
#          0.0396972 ]),
#   'elapsed_time_acf': 0.0010742000304162502,
#   'elapsed_time_tau_fit': 0.0071870998945087194}}
