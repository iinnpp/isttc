# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_folder = 'Q:\\Personal\\Irina\\projects\\isttc\\results\\monkey\\fixation_period_1500ms\\'

# %%
sttc_df = pd.read_pickle(results_folder + 'not_binned_sttc\\' + 'tau_bsl_sua_sttc_50ms_20lags_df.pkl')
pearson_df = pd.read_pickle(results_folder + 'binned_pearson\\' + 'tau_bsl_sua_pearson_50ms_20lags_df.pkl')

print('let sttc_df {}, len pearson_df {}'.format(len(sttc_df), len(pearson_df)))
# Out:
# let sttc_df 33018, len pearson_df 33018

# %%
sttc_df
# Out:
#        unit_id  trial_id  condition_id  \
# 0            0         0             0
# 1            0         1             0
# 2            0         2             0
# 3            0         3             0
# 4            0         4             0
# ...        ...       ...           ...
# 33013      543         4             0
# 33014      543        15             3
# 33015      543        18             4
# 33016      543        19             4
# 33017      543        43             7
#
#                                                      acf  acf_decay_1_4 popt  \
# 0      [1.0, 0.8489484018632951, -0.00113918284392739...           True  NaN
# 1      [1.0, 0.8282696315133622, -0.00096716195128570...           True  NaN
# 2      [1.0, 0.9364009358691534, -0.00158208041363358...           True  NaN
# 3      [1.0, 0.952130935540541, -0.0036190179375303, ...           True  NaN
# 4      [1.0, 0.9499327904161492, -0.00072707989629978...           True  NaN
# ...                                                  ...            ...  ...
# 33013  [1.0, nan, nan, nan, nan, nan, nan, nan, nan, ...          False  NaN
# 33014  [1.0, 0.7499735710761858, -8.844879836493058e-...           True  NaN
# 33015  [1.0, nan, nan, nan, nan, nan, nan, nan, nan, ...          False  NaN
# 33016  [1.0, 0.4162031679592444, -0.00057103064066852...           True  NaN
# 33017  [1.0, nan, nan, nan, nan, nan, nan, nan, nan, ...          False  NaN
#
#       pcov  r_squared  tau  tau_ms  ...    acf_15    acf_16    acf_17  \
# 0      NaN        NaN  NaN     NaN  ... -0.001140 -0.001140 -0.001140
# 1      NaN        NaN  NaN     NaN  ... -0.000968 -0.000968 -0.000968
# 2      NaN        NaN  NaN     NaN  ... -0.001583 -0.001583 -0.001583
# 3      NaN        NaN  NaN     NaN  ... -0.003621 -0.003621 -0.003621
# 4      NaN        NaN  NaN     NaN  ... -0.000727 -0.000727 -0.000728
# ...    ...        ...  ...     ...  ...       ...       ...       ...
# 33013  NaN        NaN  NaN     NaN  ...       NaN       NaN       NaN
# 33014  NaN        NaN  NaN     NaN  ... -0.000088 -0.000088 -0.000088
# 33015  NaN        NaN  NaN     NaN  ...       NaN       NaN       NaN
# 33016  NaN        NaN  NaN     NaN  ... -0.000572 -0.000572 -0.000572
# 33017  NaN        NaN  NaN     NaN  ...       NaN       NaN       NaN
#
#          acf_18    acf_19    acf_20  popt_0  popt_1  popt_2  acf_fit_failed
# 0     -0.001140 -0.001140 -0.001140     NaN     NaN     NaN            True
# 1     -0.000968 -0.000968 -0.000968     NaN     NaN     NaN            True
# 2     -0.001583 -0.001583 -0.001583     NaN     NaN     NaN            True
# 3     -0.003621 -0.003621 -0.003621     NaN     NaN     NaN            True
# 4     -0.000728 -0.000728 -0.000728     NaN     NaN     NaN            True
# ...         ...       ...       ...     ...     ...     ...             ...
# 33013       NaN       NaN       NaN     NaN     NaN     NaN            True
# 33014 -0.000088 -0.000089 -0.000089     NaN     NaN     NaN            True
# 33015       NaN       NaN       NaN     NaN     NaN     NaN            True
# 33016 -0.000572 -0.000572 -0.000572     NaN     NaN     NaN            True
# 33017       NaN       NaN       NaN     NaN     NaN     NaN            True
#
# [33018 rows x 35 columns]

# %%
sttc_df.iloc[0]
# Out:
# unit_id                                                           0
# trial_id                                                          0
# condition_id                                                      0
# acf               [1.0, 0.8489484018632951, -0.00113918284392739...
# acf_decay_1_4                                                  True
# popt                                                            NaN
# pcov                                                            NaN
# r_squared                                                       NaN
# tau                                                             NaN
# tau_ms                                                          NaN
# acf_0                                                           1.0
# acf_1                                                      0.848948
# acf_2                                                     -0.001139
# acf_3                                                     -0.001139
# acf_4                                                     -0.001139
# acf_5                                                     -0.001139
# acf_6                                                     -0.001139
# acf_7                                                     -0.001139
# acf_8                                                     -0.001139
# acf_9                                                     -0.001139
# acf_10                                                     -0.00114
# acf_11                                                     -0.00114
# acf_12                                                     -0.00114
# acf_13                                                     -0.00114
# acf_14                                                     -0.00114
# acf_15                                                     -0.00114
# acf_16                                                     -0.00114
# acf_17                                                     -0.00114
# acf_18                                                     -0.00114
# acf_19                                                     -0.00114
# acf_20                                                     -0.00114
# popt_0                                                          NaN
# popt_1                                                          NaN
# popt_2                                                          NaN
# acf_fit_failed                                                 True
# Name: 0, dtype: object

# %%
pearson_df.iloc[0]
# Out:
# unit_id                                                           0
# trial_id                                                          0
# condition_id                                                      0
# acf               [1.0, -0.016595339990489767, -0.11022349025202...
# acf_decay_1_4                                                 False
# popt              [840.092672156566, 11.014596408154562, -0.0304...
# pcov              [[1.077075998679899e+17, 132991388600829.8, 16...
# r_squared                                                   0.00123
# tau                                                        0.090789
# tau_ms                                                     4.539431
# acf_0                                                           1.0
# acf_1                                                     -0.016595
# acf_2                                                     -0.110223
# acf_3                                                      0.119971
# acf_4                                                     -0.064955
# acf_5                                                      0.036852
# acf_6                                                     -0.019686
# acf_7                                                      0.033619
# acf_8                                                      0.049834
# acf_9                                                     -0.068046
# acf_10                                                    -0.185925
# acf_11                                                     0.057109
# acf_12                                                     0.043367
# acf_13                                                    -0.098764
# acf_14                                                    -0.112506
# acf_15                                                     -0.03495
# acf_16                                                    -0.128578
# acf_17                                                    -0.185117
# acf_18                                                     0.057917
# acf_19                                                    -0.041417
# acf_20                                                     0.073229
# popt_0                                                   840.092672
# popt_1                                                    11.014596
# popt_2                                                    -0.030435
# acf_fit_failed                                                False
# Name: 0, dtype: object
